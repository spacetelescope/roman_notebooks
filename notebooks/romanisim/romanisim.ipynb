# %% [markdown]
# # Simulating WFI Imaging Data with Roman I-Sim

# %% [markdown]
# ***

# %% [markdown]
# ## Nexus Server Information
#
# IMPORTANT: To run this tutorial, please make sure you are logged in the RRN with a medium server.
#
# ## Kernel Information and Read-Only Status
#
# To run this notebook, please select "Roman Research Nexus {VERSION}" kernel at the top right of your window. For example "Roman Research Nexus 2026.1".
#
# This notebook is read-only. You can run cells and make edits, but you must save changes to a different location. We recommend saving the notebook within your home directory, or to a new folder within your home (e.g. <span style="font-variant:small-caps;">file > save notebook as > my-nbs/nb.ipynb</span>). Note that a directory must exist before you attempt to add a notebook to it.

# %% [markdown]
# ## Introduction
#
# The purpose of this notebook is to show how to generate simulated Level 1 (L1; uncalibrated ramp cubes) and Level 2 (L2; calibrated rate images) Roman Wide Field Instrument (WFI) Advanced Scientific Data Format (ASDF) files with [Roman I-Sim](https://romanisim.readthedocs.io/en/latest/) (package name `romanisim`). Details about the Roman data levels can be found in the [Data Levels and Products](https://roman-docs.stsci.edu/data-handbook-home/wfi-data-format/data-levels-and-products) article in the Roman Documentation System (RDox). Briefly, a L1 file contains a single uncalibrated ramp exposure in units of Data Numbers (DN).  L1 files are three-dimensional data cubes, one dimension for time and two dimensions for image coordinates, that are shaped as  arrays with (N resultants, 4096 image rows, 4096 image columns). A resultant is a sample up-the-ramp, and represents either a single read of the WFI detectors or multiple reads that have been combined. The L2 WFI data are calibrated images in instrumental units of DN / second.  They are two-dimensional arrays shaped as (4088 image rows, 4088 image columns).
#
# In this tutorial we first gather reference data for ancilliary packages as well as import all the packages used in the notebook. Later in the notebook we also offer options to import optimization packages for more advanced use cases.

# %% [markdown]
# ## Reference Data
#
# The cell below will check to ensure ancillary reference files for the `stpsf` package are installed. If not, it will download the ancillary reference files and install them under your home directory (i.e., `${HOME}/refdata/`).
#
# ### Local Run Settings
#
# If you want to run the notebook in your local machine, refer to the information in the [local installation](../../markdown/local-run.md) instructions before proceeding with the notebook. The instructions provide inportant information about setting up your environment, installing dependnecies, and adding to your working directory scripts to help with the reference data installation.
#
# Depending on which (if any) reference data are missing, this cell may take several minutes to execute.
#
# ### On the Roman Research Nexus
#
# If you are working on the Nexus, all the environment variables are defined and the ancillary reference data are pre-installed, so this cell will execute instantly.

# %%
import os
import sys
import importlib.util

try:
    import notebook_data_dependencies as ndd
    local = True
except ImportError:
    local = False

# If running locally Get the directory with the script
if not local:
    notebook_dir = os.getcwd()
    shared_path = os.path.abspath(
        os.path.join(notebook_dir, '..', '..', 'shared', 'notebook_data_dependencies.py')
    )

    if os.path.exists(shared_path):
        print(f"Loading notebook_data_dependencies from shared location: {shared_path}")
        spec = importlib.util.spec_from_file_location("notebook_data_dependencies", shared_path)
        ndd = importlib.util.module_from_spec(spec)
        sys.modules['notebook_data_dependencies'] = ndd  # Optional: makes subsequent imports work
        spec.loader.exec_module(ndd)
    else:
        raise FileNotFoundError(f"Local install script not found at {shared_path}")

if not local:
    print("Running local data dependency installation...")
    result = ndd.install_files(packages=['stpsf'])

    # Update environment variables (if necessary) and print reference data paths
    print('Reference data paths set to:')
    for k, v in result.items():
        if not v['pre_installed']:
            os.environ[k] = v['path']
        print(f"\t{k} = {v['path']}")

else:
    print("Running on RNN — data already available, skipping local install.")
# Out:
# Running on RNN — data already available, skipping local install.

# %% [markdown]
# ## Imports
#  Libraries used
# - *asdf* for opening Roman WFI ASDF files
# - *astroquery.gaia* for querying the Gaia catalog
# - *astropy.coordinates* for storing celestial coordinates as Python objects
# - *astropy.time* for storing time information as Python objects
# - *astropy.table* for working with Astropy Table objects
# - *astropy.units* for handling and combining units
# - *astropy.visualization* for image normalization
# - *copy* for making copies of Python objects
# - *galsim* for image simulations
# - *importlib* for reloading Python modules
# - *matplotlib* for displaying images
# - *numpy* for array operations
# - *os* for file operations
# - *romanisim* for image simulations
# - *roman_datamodels* for opening Roman WFI ASDF files
# - *s3fs* for accessing files in an S3 bucket
# - *stpsf* for making PSF profiles at specific detector location.
#
# In the [Advanced Use Cases](#Advanced-Use-Cases) section further below, we include some additional imports:
# - *pysiaf* for determining dither positions
# - *dataclasses* for creating a class
# - *typing* for doing type checking on inputs
# - *dask* for parallelization
#
# **Note:** `dask` is not installed in the Roman Calibration kernel by default. In the [Advanced Use Cases - Parallelized Simulations](#Parallelized-Simulations) section, the code cells have been commented out and there is a cell at the beginning of the section that will use `pip` to install the required packages.

# %%
import asdf
from astroquery.gaia import Gaia
from astropy.coordinates import SkyCoord
from astropy.time import Time
from astropy.table import Table, vstack
from astropy import units as u
from astropy.visualization import simple_norm
import copy
import galsim
import importlib
import matplotlib.pyplot as plt
import numpy as np
import os
import roman_datamodels as rdm
from romanisim import gaia, bandpass, catalog, log, wcs, persistence, parameters, ris_make_utils as ris, image as risim
from romanisim.image import inject_sources_into_l2
import s3fs
import stpsf
# Out:
# Please note the archive will not be accessible on 27 July at 11:30 CEST, for some minutes, due to maintenance tasks. Apologies for the inconveniences.
# 2026-07-26 03:10:43 INFO     NumExpr defaulting to 8 threads.

# %% [markdown]
# ***

# %% [markdown]
# ## Tutorial Data
#
# In this tutorial, we will create necessary data in memory or retrieve it from a catalog service. A catalog file is also available in the RRN S3 bucket, and can be streamed into memory using `astropy.table.Table` and the `s3fs` package instructions in the [Data Discovery and Access](../data_discovery_and_access/data_discovery_and_access.ipynb) tutorial. Also see the [RRN documentation](../../markdown/simulated-data.md) for more information on the catalog available in the S3 bucket.

# %% [markdown]
# ## Source Catalog Generation
#
# The `romanisim` package offers two options for generating source catalogs:
# 1. Retrieve the source catalog from Gaia; or
# 2. Parametrically generate a catalog of stars and/or galaxies.
#
# First, let's explore how to create a `romanisim`-compatible source catalog using Gaia. We will use a combination of `astroquery` and `romanisim` to query the Gaia catalog and then write the file in a format compatible with `romanisim`.
#
# In the example below, we query the Gaia DR3 catalog for sources centered at (RA, Dec) = (270.94, -0.2) degrees within a radius of 1 degree.
#
# **Note:** The Gaia query may take several minutes to complete.

# %%
ra = 270.94   # Right ascension in degrees
dec = -0.2    # Declination in degrees
radius = 1.0  # Search radius in degrees

# Try online query first
try:
    query = f"""
    SELECT * 
    FROM gaiadr3.gaia_source 
    WHERE 1 = CONTAINS(
        POINT('ICRS', {ra}, {dec}),
        CIRCLE('ICRS', ra, dec, {radius})
    )
    """
    
    print("Launching async Gaia query...")
    job = Gaia.launch_job_async(query)
    result = job.get_results()
    print(f"Query successful! Retrieved {len(result)} sources.")
    
except Exception as e:
    print(f"Gaia query failed: {e}")
    print("Trying to load local catalog from directory...")
    
    local_file = "./catalog_gaia-270p94_m0p2-result.ecsv"
    
    if os.path.exists(local_file):
        print(f"Loading {local_file} ...")
        result = Table.read(local_file, format='ascii.ecsv')
        print(f"Successfully loaded local catalog with {len(result)} sources.")
    else:
        print(f"Local file '{local_file}' not found in current directory.")
        print("Current directory contents:")
        print(os.listdir('.'))
        result = None

# If you got results (online or local)
if result is not None:
    #print(result.info)
    # show first few rows
    print(result[:5])
else:
    print("No catalog available.")
# Out:
# Launching async Gaia query...
# 2026-07-26 05:14:23 INFO     Query finished.
# INFO: Query finished. [astroquery.utils.tap.core]
# Query successful! Retrieved 306814 sources.
#     solution_id             designation          ... libname_gspphot
#                                                  ...
# ------------------- ---------------------------- ... ---------------
# 1636148068921376768 Gaia DR3 4179306919097309440 ...           MARCS
# 1636148068921376768 Gaia DR3 4179306919097335680 ...
# 1636148068921376768 Gaia DR3 4179307022176616576 ...
# 1636148068921376768 Gaia DR3 4179307026477535360 ...
# 1636148068921376768 Gaia DR3 4179307232632289408 ...

# %% [markdown]
# Once we have the result from the Gaia query, we can transform it into a format compatible with Roman I-Sim:

# %%
# Filter the Gaia results for stars and exclude bright stars
result = result[result['classprob_dsc_combmod_star'] >= 0.7]
result = result[result['phot_g_mean_mag'] > 16.5]

# Set the observation time
obs_time = '2026-10-31T00:00:00'

# Make the Roman I-Sim formatted catalog
gaia_catalog = gaia.gaia2romanisimcat(result, Time(obs_time), fluxfields=set(bandpass.galsim2roman_bandpass.values()))

# %% [markdown]
# We have excluded very bright stars (Gaia g-band > 16.5 mag in this example) because Roman I-Sim uses a maximum size of the simulated point spread function (PSF) in pixels that can result in the appearance of box-shaped boundaries around bright sources. This will be fixed in a future update.
#
# When using a real catalog like Gaia, it is essential to remove any entries with missing information. This can be achieved with the code in the cell below:

# %%
# Reject anything with missing fluxes or positions
names = [f for f in gaia_catalog.dtype.names if f[0] == 'F']
names += ['ra', 'dec']

bad = np.zeros(len(gaia_catalog), dtype='bool')
for b in names:
    bad = ~np.isfinite(gaia_catalog[b])
    if hasattr(gaia_catalog[b], 'mask'):
        bad = gaia_catalog[b].mask
    gaia_catalog = gaia_catalog[~bad]

# %% [markdown]
# Now that we have a catalog, let's take a look at it. The catalog in memory is an `astropy.table.Table` object with over 1e5 rows:

# %%
gaia_catalog
# Out:
# <Table length=242479>
#         ra                 dec          ...          F146
#      float64             float64        ...        float64
# ------------------ -------------------- ... ----------------------
# 269.99556833474514  -0.5153686985148954 ...  4.453445444244283e-08
# 269.99857867515965  -0.5091925233797133 ... 2.5630046236381587e-08
# 269.99369961265984  -0.4947976090170517 ... 1.4801210707489509e-08
#  269.9974539783147 -0.48975487534172074 ...  1.631640058361595e-08
#  269.9916566781788 -0.49074850696407196 ... 1.1705312862630533e-08
# 269.99891226347086  -0.4771143072821228 ...  5.875144528123327e-08
# 269.99498980449675  -0.4584007154938247 ...   8.52024268951623e-09
#  269.9750938243964 -0.45516614685890483 ... 3.5485889395606015e-08
#  269.9983871538959 -0.44846896942283615 ... 1.1138740597782383e-08
#                ...                  ... ...                    ...
#  270.5829642114862   0.3230408132658312 ...  9.984008961576367e-09
#  270.5634878126435   0.3285326766862687 ... 1.1364720959284407e-08
# 270.58037578414434  0.23357161716580424 ... 1.5925515747733783e-08
# 270.57114009357207  0.23457185908132488 ...  9.097398866202034e-09
#  270.5674694237085  0.23082260031765592 ...  5.350706165321897e-09
# 270.48880702821486  0.20038021535491457 ... 5.2736432606399715e-09
#  270.4865682283135  0.20000764974715637 ...  9.799296891201488e-09
#  270.4936534043312  0.20965345978003544 ... 3.3334936155699055e-08
#  270.4831289248765  0.21653588860737397 ... 1.3525255480119356e-07
#  270.5100609352293  0.21465058301118353 ... 3.8506352230776575e-08

# %% [markdown]
# Alternatively, we can generate a completely synthetic catalog of stars and galaxies using tools in Roman I-Sim (see parameters in the cell below). In this tutorial, we will simulate a galaxy catalog and merge it with the Gaia star catalog. This approach addresses the limitation of Gaia's catalog, which includes only relatively bright sources, by adding galaxies. At the same time, real Gaia point sources are necessary for the Roman calibration pipeline to match images to Gaia astrometry.
#
# Note that we can additionally simulate a star catalog if desired. This may be useful for including stars fainter than the Gaia magnitude limit, or when the Gaia astrometric step in RomanCal is not required.
#
# Note that in the cell below, we have commented out the last line, which would save the catalog to disk as an Enhanced Character-Separated Values (ECSV) file. We do not need the catalog to be saved on disk for this tutorial, but you may optionally uncomment the line to save the file if you wish. The same file is available in the S3 bucket for any other tutorials that may need it. Having a saved version of the catalog removes the need to re-run the Gaia query above if you need to start over, but you will need to add code to read the catalog file below.

# %%
# Galaxy catalog parameters

ra = 270.94  # Right ascension of the catalog center in degrees
dec = -0.2  # Declination of the catalog center in degrees
radius = 1.0  # Radius of the catalog in degrees
n_gal = 30_000  # Number of galaxies
faint_mag = 22  # Faint magnitude limit of simulated sources
hlight_radius = 0.3  # Half-light radius at the faint magnitude limit in units of arcseconds
optical_element = 'F062 F087 F106 F129 F146 F158 F184 F213'.split()  # List of optical elements to simulate
seed = 4642  # Random number seed for reproducibility

# Create galaxy catalog
galaxy_cat = catalog.make_galaxies(SkyCoord(ra, dec, unit='deg'), n_gal, radius=radius, index=0.4, faintmag=faint_mag,
                                   hlr_at_faintmag=hlight_radius, bandpasses=optical_element, rng=None, seed=seed)

# Merge the galaxy and Gaia catalogs
full_catalog = vstack([galaxy_cat, gaia_catalog])

# To save the catalog to disk, uncomment the following line
#full_catalog.write('full_catalog.ecsv', format='ascii.ecsv', overwrite=True)

# %% [markdown]
# The following cell is commented out, but if uncommented will create a simulated star catalog.

# %%
#n_star = 30_000  # Number of stars

#star_cat = catalog.make_stars(SkyCoord(ra, dec, unit='deg'), n_star, radius=radius, index=5/3., faintmag=faint_mag, 
#                              truncation_radius=None, bandpasses=optical_element, rng=None, seed=seed)

# %% [markdown]
# As before, we have commented out the line that will write this to disk, and instead have kept it in memory. Below, let's print out the catalog and take a look:

# %%
full_catalog
# Out:
# <Table length=272479>
#         ra                 dec          ...          F213
#      float64             float64        ...        float64
# ------------------ -------------------- ... ----------------------
#  271.6295510520961 -0.03965028067096237 ...  2.402744225804554e-09
#  270.7539155586658   -1.175434326974954 ...  1.096286439405958e-08
#  270.8648924331985   0.5861049874846664 ...  6.596417634341378e-09
# 270.70544440611565  -0.1905627389524337 ... 5.4636619672976394e-09
#  271.0763272819082  0.28776831750222365 ... 1.8613071972595208e-07
#  271.1748280956513    0.707003102302135 ... 2.7085311771202214e-09
#  270.2732744737068  -0.5242855117710061 ...  2.141273469646876e-08
#  271.4612060810417  0.48981218301356017 ...  1.902641377782288e-09
#  270.5213999343187   0.3768383558530194 ... 2.2672709931725876e-08
#                ...                  ... ...                    ...
#  270.5829642114862   0.3230408132658312 ...  9.984008961576367e-09
#  270.5634878126435   0.3285326766862687 ... 1.1364720959284407e-08
# 270.58037578414434  0.23357161716580424 ... 1.5925515747733783e-08
# 270.57114009357207  0.23457185908132488 ...  9.097398866202034e-09
#  270.5674694237085  0.23082260031765592 ...  5.350706165321897e-09
# 270.48880702821486  0.20038021535491457 ... 5.2736432606399715e-09
#  270.4865682283135  0.20000764974715637 ...  9.799296891201488e-09
#  270.4936534043312  0.20965345978003544 ... 3.3334936155699055e-08
#  270.4831289248765  0.21653588860737397 ... 1.3525255480119356e-07
#  270.5100609352293  0.21465058301118353 ... 3.8506352230776575e-08

# %% [markdown]
# We can see galaxies at the top of the stacked catalog (notice type == "SER" for Sersic and values of n (the Sersic index) are not -1, while stars have type == PSF).

# %% [markdown]
# If using an existing catalog, here we provide with the command to read it

# %%
# Read saved catalog
#full_catalog = Table.read('full_catalog.ecsv')

# %% [markdown]
# ### Image Simulation
# Here we show how to run the actual simulation using Roman I-Sim. The method for running the simulation for both L1 and L2 data is the same, so we will show an example for L2, and give instructions of how to modify this for L1.
#
# In our example, we are simulating only a single image, so we have set the persistance to the default. Future updates may include how to simulate persistance from multiple exposures.
#
# **Notes:**
#
# - Roman I-Sim allows the user to either use reference files from CRDS or to use no reference files. The latter is not recommended.
# - Each detector is simulated separately. Below, in the [Advanced Use Cases - Parallelized Simulations](#Parallelized-Simulations) section, we include instructions on how to parallelize the simulations using Dask.
# - Currently, the simulator does not include the effect of 1/f noise.
# - Multi-accumulation (MA) tables control the total exposure time and sampling up-the-ramp. For more information, see the [MA table article](https://roman-docs.stsci.edu/raug/astronomers-proposal-tool-apt/appendix/appendix-wfi-multiaccum-tables) in the Roman APT Users Guide.
#
# In this case, we will create an observation using the detector WFI01 and the F106 optical element. The observation is simulated to occur at UTC time 2026-10-31T00:00:00 and an exposure time of approximately 60 seconds.
#
# **Note:** It will take several minutes to download the appropriate calibration reference files the first time this cell is run. Any changes to the settings below may require downloading additional files, which could increase the run time.
#
# **Note** To avoid writing files unnecessarily and reduce I/O overdead, the simulated file is not saved to disk. This provides batch processing flesibility, where you inspect/modify your file before saving. For simplicity, the command to save your file is also provided.

# %%
# WFI data level to simulate...1 or 2
level = 2

# Other important parameters
obs_date = '2026-10-31T00:00:00'  # Datetime of the simulated exposure
optical_element = 'F106'  # Optical element to simulate
ma_table_number = 1018  # Multi-accumulation (MA) table number (see RDox for more information)
seed = 7  # Galsim random number generator seed for reproducibility
sca = 1  # Change this number to simulate different WFI detectors 1 - 18

# If using CRDS, set reference_data to None
for k in parameters.reference_data:
    parameters.reference_data[k] = None

# Set Galsim RNG object
rng = galsim.UniformDeviate(seed)

# Set default persistance information
persist = persistence.Persistence()

# Set metadata for use in Roman I-Sim.
metadata = ris.set_metadata(date=obs_date, bandpass=optical_element,
                            sca=sca, ma_table_number=ma_table_number, usecrds=True)

# Update the WCS info
wcs.fill_in_parameters(metadata, SkyCoord(ra, dec, unit='deg', frame='icrs'),
                       boresight=False, pa_aper=0.0)

# Run the simulation using metadata valueswithout saving any files
im, extras = risim.simulate(metadata, full_catalog, usecrds=True,
                            psftype='stpsf', level=level,
                            persistence=None, rng=rng
                            )
# Out:
# CRDS - INFO -  Fetching  /home/runner/crds_cache/mappings/roman/roman_wfi_specpsf_0001.rmap      572 bytes  (1 / 30 files) (0 / 77.6 K bytes)
# CRDS - INFO -  Fetching  /home/runner/crds_cache/mappings/roman/roman_wfi_skycells_0002.rmap      712 bytes  (2 / 30 files) (572 / 77.6 K bytes)
# CRDS - INFO -  Fetching  /home/runner/crds_cache/mappings/roman/roman_wfi_sflat_0001.rmap      548 bytes  (3 / 30 files) (1.3 K / 77.6 K bytes)
# CRDS - INFO -  Fetching  /home/runner/crds_cache/mappings/roman/roman_wfi_saturation_0003.rmap    2.4 K bytes  (4 / 30 files) (1.8 K / 77.6 K bytes)
# CRDS - INFO -  Fetching  /home/runner/crds_cache/mappings/roman/roman_wfi_relflux_0001.rmap      555 bytes  (5 / 30 files) (4.3 K / 77.6 K bytes)
# CRDS - INFO -  Fetching  /home/runner/crds_cache/mappings/roman/roman_wfi_refpix_0003.rmap    2.3 K bytes  (6 / 30 files) (4.8 K / 77.6 K bytes)
# CRDS - INFO -  Fetching  /home/runner/crds_cache/mappings/roman/roman_wfi_readnoise_0006.rmap    3.4 K bytes  (7 / 30 files) (7.1 K / 77.6 K bytes)
# CRDS - INFO -  Fetching  /home/runner/crds_cache/mappings/roman/roman_wfi_photom_0004.rmap    2.3 K bytes  (8 / 30 files) (10.5 K / 77.6 K bytes)
# CRDS - INFO -  Fetching  /home/runner/crds_cache/mappings/roman/roman_wfi_optmodel_0001.rmap      586 bytes  (9 / 30 files) (12.9 K / 77.6 K bytes)
# CRDS - INFO -  Fetching  /home/runner/crds_cache/mappings/roman/roman_wfi_matable_0004.rmap      690 bytes  (10 / 30 files) (13.4 K / 77.6 K bytes)
# CRDS - INFO -  Fetching  /home/runner/crds_cache/mappings/roman/roman_wfi_mask_0003.rmap    2.3 K bytes  (11 / 30 files) (14.1 K / 77.6 K bytes)
# CRDS - INFO -  Fetching  /home/runner/crds_cache/mappings/roman/roman_wfi_linearity_0005.rmap    2.4 K bytes  (12 / 30 files) (16.4 K / 77.6 K bytes)
# CRDS - INFO -  Fetching  /home/runner/crds_cache/mappings/roman/roman_wfi_ipc_0003.rmap    3.3 K bytes  (13 / 30 files) (18.8 K / 77.6 K bytes)
# CRDS - INFO -  Fetching  /home/runner/crds_cache/mappings/roman/roman_wfi_inverselinearity_0005.rmap    2.6 K bytes  (14 / 30 files) (22.1 K / 77.6 K bytes)
# CRDS - INFO -  Fetching  /home/runner/crds_cache/mappings/roman/roman_wfi_integralnonlinearity_0002.rmap    2.8 K bytes  (15 / 30 files) (24.7 K / 77.6 K bytes)
# CRDS - INFO -  Fetching  /home/runner/crds_cache/mappings/roman/roman_wfi_gain_0003.rmap    2.3 K bytes  (16 / 30 files) (27.5 K / 77.6 K bytes)
# CRDS - INFO -  Fetching  /home/runner/crds_cache/mappings/roman/roman_wfi_flat_0006.rmap    8.5 K bytes  (17 / 30 files) (29.7 K / 77.6 K bytes)
# CRDS - INFO -  Fetching  /home/runner/crds_cache/mappings/roman/roman_wfi_etc_0002.rmap    2.3 K bytes  (18 / 30 files) (38.2 K / 77.6 K bytes)
# CRDS - INFO -  Fetching  /home/runner/crds_cache/mappings/roman/roman_wfi_epsf_0004.rmap   16.3 K bytes  (19 / 30 files) (40.5 K / 77.6 K bytes)
# CRDS - INFO -  Fetching  /home/runner/crds_cache/mappings/roman/roman_wfi_dustmap_0003.rmap      855 bytes  (20 / 30 files) (56.8 K / 77.6 K bytes)
# CRDS - INFO -  Fetching  /home/runner/crds_cache/mappings/roman/roman_wfi_distortion_0002.rmap    3.6 K bytes  (21 / 30 files) (57.7 K / 77.6 K bytes)
# CRDS - INFO -  Fetching  /home/runner/crds_cache/mappings/roman/roman_wfi_detectorstatus_0002.rmap      773 bytes  (22 / 30 files) (61.2 K / 77.6 K bytes)
# CRDS - INFO -  Fetching  /home/runner/crds_cache/mappings/roman/roman_wfi_darkdecaysignal_0002.rmap      783 bytes  (23 / 30 files) (62.0 K / 77.6 K bytes)
# CRDS - INFO -  Fetching  /home/runner/crds_cache/mappings/roman/roman_wfi_dark_0011.rmap    4.4 K bytes  (24 / 30 files) (62.8 K / 77.6 K bytes)
# CRDS - INFO -  Fetching  /home/runner/crds_cache/mappings/roman/roman_wfi_area_0002.rmap    2.3 K bytes  (25 / 30 files) (67.2 K / 77.6 K bytes)
# CRDS - INFO -  Fetching  /home/runner/crds_cache/mappings/roman/roman_wfi_apcorr_0003.rmap    2.3 K bytes  (26 / 30 files) (69.5 K / 77.6 K bytes)
# CRDS - INFO -  Fetching  /home/runner/crds_cache/mappings/roman/roman_wfi_abvegaoffset_0002.rmap    2.5 K bytes  (27 / 30 files) (71.8 K / 77.6 K bytes)
# CRDS - INFO -  Fetching  /home/runner/crds_cache/mappings/roman/roman_wfi_absflux_0001.rmap      555 bytes  (28 / 30 files) (74.3 K / 77.6 K bytes)
# CRDS - INFO -  Fetching  /home/runner/crds_cache/mappings/roman/roman_wfi_0056.imap    2.4 K bytes  (29 / 30 files) (74.8 K / 77.6 K bytes)
# CRDS - INFO -  Fetching  /home/runner/crds_cache/mappings/roman/roman_0058.pmap       344 bytes  (30 / 30 files) (77.3 K / 77.6 K bytes)
# CRDS - INFO -  Fetching  /home/runner/crds_cache/references/roman/wfi/roman_wfi_matable_0003.asdf  728.3 K bytes  (1 / 1 files) (0 / 728.3 K bytes)
# CRDS - INFO -  Fetching  /home/runner/crds_cache/mappings/roman/roman_wfi_readnoise_0005.rmap    3.2 K bytes  (1 / 24 files) (0 / 26.9 K bytes)
# CRDS - INFO -  Fetching  /home/runner/crds_cache/mappings/roman/roman_wfi_pars-tweakregstep_0001.rmap      568 bytes  (2 / 24 files) (3.2 K / 26.9 K bytes)
# CRDS - INFO -  Fetching  /home/runner/crds_cache/mappings/roman/roman_wfi_pars-sourcedetectionstep_0001.rmap      643 bytes  (3 / 24 files) (3.8 K / 26.9 K bytes)
# CRDS - INFO -  Fetching  /home/runner/crds_cache/mappings/roman/roman_wfi_pars-skymatchstep_0001.rmap      568 bytes  (4 / 24 files) (4.5 K / 26.9 K bytes)
# CRDS - INFO -  Fetching  /home/runner/crds_cache/mappings/roman/roman_wfi_pars-saturationstep_0001.rmap      580 bytes  (5 / 24 files) (5.0 K / 26.9 K bytes)
# CRDS - INFO -  Fetching  /home/runner/crds_cache/mappings/roman/roman_wfi_pars-resamplestep_0001.rmap      568 bytes  (6 / 24 files) (5.6 K / 26.9 K bytes)
# CRDS - INFO -  Fetching  /home/runner/crds_cache/mappings/roman/roman_wfi_pars-refpixstep_0001.rmap      556 bytes  (7 / 24 files) (6.2 K / 26.9 K bytes)
# CRDS - INFO -  Fetching  /home/runner/crds_cache/mappings/roman/roman_wfi_pars-rampfitstep_0001.rmap      574 bytes  (8 / 24 files) (6.7 K / 26.9 K bytes)
# CRDS - INFO -  Fetching  /home/runner/crds_cache/mappings/roman/roman_wfi_pars-photomstep_0001.rmap      556 bytes  (9 / 24 files) (7.3 K / 26.9 K bytes)
# CRDS - INFO -  Fetching  /home/runner/crds_cache/mappings/roman/roman_wfi_pars-outlierdetectionstep_0001.rmap      649 bytes  (10 / 24 files) (7.9 K / 26.9 K bytes)
# CRDS - INFO -  Fetching  /home/runner/crds_cache/mappings/roman/roman_wfi_pars-linearitystep_0001.rmap      574 bytes  (11 / 24 files) (8.5 K / 26.9 K bytes)
# CRDS - INFO -  Fetching  /home/runner/crds_cache/mappings/roman/roman_wfi_pars-jumpstep_0001.rmap      712 bytes  (12 / 24 files) (9.1 K / 26.9 K bytes)
# CRDS - INFO -  Fetching  /home/runner/crds_cache/mappings/roman/roman_wfi_pars-highlevelpipeline_0001.rmap      807 bytes  (13 / 24 files) (9.8 K / 26.9 K bytes)
# CRDS - INFO -  Fetching  /home/runner/crds_cache/mappings/roman/roman_wfi_pars-fluxstep_0001.rmap      544 bytes  (14 / 24 files) (10.6 K / 26.9 K bytes)
# CRDS - INFO -  Fetching  /home/runner/crds_cache/mappings/roman/roman_wfi_pars-flatfieldstep_0001.rmap      574 bytes  (15 / 24 files) (11.1 K / 26.9 K bytes)
# CRDS - INFO -  Fetching  /home/runner/crds_cache/mappings/roman/roman_wfi_pars-exposurepipeline_0001.rmap      800 bytes  (16 / 24 files) (11.7 K / 26.9 K bytes)
# CRDS - INFO -  Fetching  /home/runner/crds_cache/mappings/roman/roman_wfi_pars-dqinitstep_0001.rmap      556 bytes  (17 / 24 files) (12.5 K / 26.9 K bytes)
# CRDS - INFO -  Fetching  /home/runner/crds_cache/mappings/roman/roman_wfi_pars-darkcurrentstep_0001.rmap      586 bytes  (18 / 24 files) (13.1 K / 26.9 K bytes)
# CRDS - INFO -  Fetching  /home/runner/crds_cache/mappings/roman/roman_wfi_pars-assignwcsstep_0001.rmap      574 bytes  (19 / 24 files) (13.7 K / 26.9 K bytes)
# CRDS - INFO -  Fetching  /home/runner/crds_cache/mappings/roman/roman_wfi_ipc_0002.rmap    2.3 K bytes  (20 / 24 files) (14.2 K / 26.9 K bytes)
# CRDS - INFO -  Fetching  /home/runner/crds_cache/mappings/roman/roman_wfi_dark_0007.rmap    5.0 K bytes  (21 / 24 files) (16.5 K / 26.9 K bytes)
# CRDS - INFO -  Fetching  /home/runner/crds_cache/mappings/roman/roman_wfi_apcorr_0002.rmap    2.3 K bytes  (22 / 24 files) (21.5 K / 26.9 K bytes)
# CRDS - INFO -  Fetching  /home/runner/crds_cache/mappings/roman/roman_wfi_0046.imap    2.8 K bytes  (23 / 24 files) (23.8 K / 26.9 K bytes)
# CRDS - INFO -  Fetching  /home/runner/crds_cache/mappings/roman/roman_0048.pmap       344 bytes  (24 / 24 files) (26.6 K / 26.9 K bytes)
# CRDS - INFO -  Fetching  /home/runner/crds_cache/references/roman/wfi/roman_wfi_dark_0364.asdf    5.7 K bytes  (1 / 9 files) (0 / 1.2 G bytes)
# CRDS - INFO -  Fetching  /home/runner/crds_cache/references/roman/wfi/roman_wfi_darkdecaysignal_0001.asdf    2.8 K bytes  (2 / 9 files) (5.7 K / 1.2 G bytes)
# CRDS - INFO -  Fetching  /home/runner/crds_cache/references/roman/wfi/roman_wfi_distortion_0014.asdf   11.3 K bytes  (3 / 9 files) (8.5 K / 1.2 G bytes)
# CRDS - INFO -  Fetching  /home/runner/crds_cache/references/roman/wfi/roman_wfi_gain_0022.asdf   67.1 M bytes  (4 / 9 files) (19.8 K / 1.2 G bytes)
# CRDS - INFO -  Fetching  /home/runner/crds_cache/references/roman/wfi/roman_wfi_inverselinearity_0042.asdf  469.8 M bytes  (5 / 9 files) (67.1 M / 1.2 G bytes)
# CRDS - INFO -  Fetching  /home/runner/crds_cache/references/roman/wfi/roman_wfi_linearity_0039.asdf  469.8 M bytes  (6 / 9 files) (536.9 M / 1.2 G bytes)
# CRDS - INFO -  Fetching  /home/runner/crds_cache/references/roman/wfi/roman_wfi_integralnonlinearity_0003.asdf   16.9 M bytes  (7 / 9 files) (1.0 G / 1.2 G bytes)
# CRDS - INFO -  Fetching  /home/runner/crds_cache/references/roman/wfi/roman_wfi_readnoise_0024.asdf   67.1 M bytes  (8 / 9 files) (1.0 G / 1.2 G bytes)
# CRDS - INFO -  Fetching  /home/runner/crds_cache/references/roman/wfi/roman_wfi_saturation_0031.asdf  134.2 M bytes  (9 / 9 files) (1.1 G / 1.2 G bytes)
# CRDS - INFO -  Fetching  /home/runner/crds_cache/references/roman/wfi/roman_wfi_flat_0175.asdf  200.5 M bytes  (1 / 1 files) (0 / 200.5 M bytes)
# 2026-07-26 05:14:42 WARNING  7412 points with problematic saturation / inverse linearity values!
# 2026-07-26 05:14:42 INFO     Simulating filter F106...
# 2026-07-26 05:14:43 INFO     Creating PSF using stpsf
# /home/runner/micromamba/envs/ci-env/lib/python3.13/site-packages/stpsf/utils.py:250: UserWarning: Environment variable $STPSF_PATH is not set!
#
#  ***********  ERROR  ******  ERROR  ******  ERROR  ******  ERROR  ***********
#  *                                                                          *
#  *  STPSF requires several data files to operate.                         *
#  *  These files could not be located automatically at this time, or this    *
#  *  version of the software requires a newer set of reference files than    *
#  *  you have installed.  For more details see:                              *
#  *                                                                          *
#  *        https://stpsf.readthedocs.io/en/stable/installation.html        *
#  *                                                                          *
#  *  under "Installing the Required Data Files".                             *
#  *  STPSF will not be able to function properly until the appropriate     *
#  *  reference files have been downloaded to your machine and installed.     *
#  *                                                                          *
#  ****************************************************************************
#  searching default location.
#   warnings.warn(message)
# /home/runner/micromamba/envs/ci-env/lib/python3.13/site-packages/stpsf/utils.py:202: UserWarning: STPSF data files not found in default location, attempting to download them now...
#   warnings.warn("STPSF data files not found in default location, attempting to download them now...")
# /home/runner/micromamba/envs/ci-env/lib/python3.13/site-packages/stpsf/utils.py:215: UserWarning: STPSF data files downloaded and installed to /home/runner/data/stpsf-data.
#   warnings.warn(f"STPSF data files downloaded and installed to {default_path}.")
# 2026-07-26 05:14:46 INFO     Using pupil mask 'F062' and detector 'WFI01'.
# 2026-07-26 05:14:46 INFO     Using pupil mask 'F062' and detector 'WFI01'.
# 2026-07-26 05:14:46 INFO     Using pupil mask 'F106' and detector 'WFI01'.
# 2026-07-26 05:14:46 INFO     No source spectrum supplied, therefore defaulting to 5700 K blackbody
# 2026-07-26 05:14:46 INFO     Computing wavelength weights using synthetic photometry for F106...
# 2026-07-26 05:14:46 INFO     Using pupil mask 'F106' and detector 'WFI01'.
# 2026-07-26 05:14:46 INFO     PSF calc using fov_arcsec = 5.000000, oversample = 4, number of wavelengths = 10
# 2026-07-26 05:14:46 INFO     Creating optical system model:
# 2026-07-26 05:14:46 INFO     Initialized OpticalSystem: Roman+WFI
# 2026-07-26 05:14:46 INFO     Roman Entrance Pupil: Loaded amplitude transmission from /home/runner/data/stpsf-data/WFI/pupils/RST_WIM_Filter_F106_WFI01.fits.gz
# 2026-07-26 05:14:46 INFO     Roman Entrance Pupil: Loaded OPD from /home/runner/data/stpsf-data/upscaled_HST_OPD.fits
# 2026-07-26 05:14:46 INFO     Added pupil plane: Roman Entrance Pupil
# 2026-07-26 05:14:46 INFO     Added coordinate inversion plane: OTE exit pupil
# 2026-07-26 05:14:46 INFO     Added pupil plane: Field Dependent Aberration (WFI01)
# 2026-07-26 05:14:46 INFO     Added detector with pixelscale=0.1078577405 and oversampling=4: WFI detector
# 2026-07-26 05:14:46 INFO     Calculating PSF with 10 wavelengths
# 2026-07-26 05:14:46 INFO      Propagating wavelength = 9.4555e-07 m
# 2026-07-26 05:14:52 INFO      Propagating wavelength = 9.7265e-07 m
# 2026-07-26 05:14:52 INFO      Propagating wavelength = 9.9975e-07 m
# 2026-07-26 05:14:53 INFO      Propagating wavelength = 1.02685e-06 m
# 2026-07-26 05:14:53 INFO      Propagating wavelength = 1.05395e-06 m
# 2026-07-26 05:14:53 INFO      Propagating wavelength = 1.08105e-06 m
# 2026-07-26 05:14:54 INFO      Propagating wavelength = 1.10815e-06 m
# 2026-07-26 05:14:54 INFO      Propagating wavelength = 1.13525e-06 m
# 2026-07-26 05:14:54 INFO      Propagating wavelength = 1.16235e-06 m
# 2026-07-26 05:14:55 INFO      Propagating wavelength = 1.18945e-06 m
# 2026-07-26 05:14:55 INFO       Calculation completed in 8.704 s
# 2026-07-26 05:14:55 INFO     PSF Calculation completed.
# 2026-07-26 05:14:55 INFO     Calculating jitter using gaussian
# 2026-07-26 05:14:55 INFO     Jitter: Convolving with Gaussian with sigma=0.012 arcsec
# 2026-07-26 05:14:55 INFO             resulting image peak drops to 0.946 of its previous value
# 2026-07-26 05:14:55 INFO     Detector charge diffusion not applied because charge_diffusion_sigma option is 0
# 2026-07-26 05:14:55 INFO      Adding extension with image downsampled to detector pixel scale.
# 2026-07-26 05:14:55 INFO      Downsampling to detector pixel scale, by 4
# 2026-07-26 05:14:55 INFO      Downsampling to detector pixel scale, by 4
# 2026-07-26 05:14:55 INFO     Creating PSF using stpsf
# 2026-07-26 05:14:55 INFO     Using pupil mask 'F062' and detector 'WFI01'.
# 2026-07-26 05:14:55 INFO     Using pupil mask 'F062' and detector 'WFI01'.
# 2026-07-26 05:14:55 INFO     Using pupil mask 'F106' and detector 'WFI01'.
# 2026-07-26 05:14:55 INFO     No source spectrum supplied, therefore defaulting to 5700 K blackbody
# 2026-07-26 05:14:55 INFO     Computing wavelength weights using synthetic photometry for F106...
# 2026-07-26 05:14:56 INFO     Using pupil mask 'F106' and detector 'WFI01'.
# 2026-07-26 05:14:56 INFO     PSF calc using fov_arcsec = 5.000000, oversample = 4, number of wavelengths = 10
# 2026-07-26 05:14:56 INFO     Creating optical system model:
# 2026-07-26 05:14:56 INFO     Initialized OpticalSystem: Roman+WFI
# 2026-07-26 05:14:56 INFO     Roman Entrance Pupil: Loaded amplitude transmission from /home/runner/data/stpsf-data/WFI/pupils/RST_WIM_Filter_F106_WFI01.fits.gz
# 2026-07-26 05:14:56 INFO     Roman Entrance Pupil: Loaded OPD from /home/runner/data/stpsf-data/upscaled_HST_OPD.fits
# 2026-07-26 05:14:56 INFO     Added pupil plane: Roman Entrance Pupil
# 2026-07-26 05:14:56 INFO     Added coordinate inversion plane: OTE exit pupil
# 2026-07-26 05:14:56 INFO     Added pupil plane: Field Dependent Aberration (WFI01)
# 2026-07-26 05:14:56 INFO     Added detector with pixelscale=0.1078577405 and oversampling=4: WFI detector
# 2026-07-26 05:14:56 INFO     Calculating PSF with 10 wavelengths
# 2026-07-26 05:14:56 INFO      Propagating wavelength = 9.4555e-07 m
# 2026-07-26 05:14:56 INFO      Propagating wavelength = 9.7265e-07 m
# 2026-07-26 05:14:56 INFO      Propagating wavelength = 9.9975e-07 m
# 2026-07-26 05:14:57 INFO      Propagating wavelength = 1.02685e-06 m
# 2026-07-26 05:14:57 INFO      Propagating wavelength = 1.05395e-06 m
# 2026-07-26 05:14:57 INFO      Propagating wavelength = 1.08105e-06 m
# 2026-07-26 05:14:58 INFO      Propagating wavelength = 1.10815e-06 m
# 2026-07-26 05:14:58 INFO      Propagating wavelength = 1.13525e-06 m
# 2026-07-26 05:14:58 INFO      Propagating wavelength = 1.16235e-06 m
# 2026-07-26 05:14:59 INFO      Propagating wavelength = 1.18945e-06 m
# 2026-07-26 05:14:59 INFO       Calculation completed in 3.337 s
# 2026-07-26 05:14:59 INFO     PSF Calculation completed.
# 2026-07-26 05:14:59 INFO     Calculating jitter using gaussian
# 2026-07-26 05:14:59 INFO     Jitter: Convolving with Gaussian with sigma=0.012 arcsec
# 2026-07-26 05:14:59 INFO             resulting image peak drops to 0.946 of its previous value
# 2026-07-26 05:14:59 INFO     Detector charge diffusion not applied because charge_diffusion_sigma option is 0
# 2026-07-26 05:14:59 INFO      Adding extension with image downsampled to detector pixel scale.
# 2026-07-26 05:14:59 INFO      Downsampling to detector pixel scale, by 4
# 2026-07-26 05:14:59 INFO      Downsampling to detector pixel scale, by 4
# 2026-07-26 05:14:59 INFO     Creating PSF using stpsf
# 2026-07-26 05:14:59 INFO     Using pupil mask 'F062' and detector 'WFI01'.
# 2026-07-26 05:14:59 INFO     Using pupil mask 'F062' and detector 'WFI01'.
# 2026-07-26 05:14:59 INFO     Using pupil mask 'F106' and detector 'WFI01'.
# 2026-07-26 05:14:59 INFO     No source spectrum supplied, therefore defaulting to 5700 K blackbody
# 2026-07-26 05:14:59 INFO     Computing wavelength weights using synthetic photometry for F106...
# 2026-07-26 05:15:00 INFO     Using pupil mask 'F106' and detector 'WFI01'.
# 2026-07-26 05:15:00 INFO     PSF calc using fov_arcsec = 5.000000, oversample = 4, number of wavelengths = 10
# 2026-07-26 05:15:00 INFO     Creating optical system model:
# 2026-07-26 05:15:00 INFO     Initialized OpticalSystem: Roman+WFI
# 2026-07-26 05:15:00 INFO     Roman Entrance Pupil: Loaded amplitude transmission from /home/runner/data/stpsf-data/WFI/pupils/RST_WIM_Filter_F106_WFI01.fits.gz
# 2026-07-26 05:15:00 INFO     Roman Entrance Pupil: Loaded OPD from /home/runner/data/stpsf-data/upscaled_HST_OPD.fits
# 2026-07-26 05:15:00 INFO     Added pupil plane: Roman Entrance Pupil
# 2026-07-26 05:15:00 INFO     Added coordinate inversion plane: OTE exit pupil
# 2026-07-26 05:15:00 INFO     Added pupil plane: Field Dependent Aberration (WFI01)
# 2026-07-26 05:15:00 INFO     Added detector with pixelscale=0.1078577405 and oversampling=4: WFI detector
# 2026-07-26 05:15:00 INFO     Calculating PSF with 10 wavelengths
# 2026-07-26 05:15:00 INFO      Propagating wavelength = 9.4555e-07 m
# 2026-07-26 05:15:00 INFO      Propagating wavelength = 9.7265e-07 m
# 2026-07-26 05:15:00 INFO      Propagating wavelength = 9.9975e-07 m
# 2026-07-26 05:15:01 INFO      Propagating wavelength = 1.02685e-06 m
# 2026-07-26 05:15:01 INFO      Propagating wavelength = 1.05395e-06 m
# 2026-07-26 05:15:01 INFO      Propagating wavelength = 1.08105e-06 m
# 2026-07-26 05:15:02 INFO      Propagating wavelength = 1.10815e-06 m
# 2026-07-26 05:15:02 INFO      Propagating wavelength = 1.13525e-06 m
# 2026-07-26 05:15:02 INFO      Propagating wavelength = 1.16235e-06 m
# 2026-07-26 05:15:03 INFO      Propagating wavelength = 1.18945e-06 m
# 2026-07-26 05:15:03 INFO       Calculation completed in 3.319 s
# 2026-07-26 05:15:03 INFO     PSF Calculation completed.
# 2026-07-26 05:15:03 INFO     Calculating jitter using gaussian
# 2026-07-26 05:15:03 INFO     Jitter: Convolving with Gaussian with sigma=0.012 arcsec
# 2026-07-26 05:15:03 INFO             resulting image peak drops to 0.946 of its previous value
# 2026-07-26 05:15:03 INFO     Detector charge diffusion not applied because charge_diffusion_sigma option is 0
# 2026-07-26 05:15:03 INFO      Adding extension with image downsampled to detector pixel scale.
# 2026-07-26 05:15:03 INFO      Downsampling to detector pixel scale, by 4
# 2026-07-26 05:15:03 INFO      Downsampling to detector pixel scale, by 4
# 2026-07-26 05:15:03 INFO     Creating PSF using stpsf
# 2026-07-26 05:15:03 INFO     Using pupil mask 'F062' and detector 'WFI01'.
# 2026-07-26 05:15:03 INFO     Using pupil mask 'F062' and detector 'WFI01'.
# 2026-07-26 05:15:03 INFO     Using pupil mask 'F106' and detector 'WFI01'.
# 2026-07-26 05:15:03 INFO     No source spectrum supplied, therefore defaulting to 5700 K blackbody
# 2026-07-26 05:15:03 INFO     Computing wavelength weights using synthetic photometry for F106...
# 2026-07-26 05:15:04 INFO     Using pupil mask 'F106' and detector 'WFI01'.
# 2026-07-26 05:15:04 INFO     PSF calc using fov_arcsec = 5.000000, oversample = 4, number of wavelengths = 10
# 2026-07-26 05:15:04 INFO     Creating optical system model:
# 2026-07-26 05:15:04 INFO     Initialized OpticalSystem: Roman+WFI
# 2026-07-26 05:15:04 INFO     Roman Entrance Pupil: Loaded amplitude transmission from /home/runner/data/stpsf-data/WFI/pupils/RST_WIM_Filter_F106_WFI01.fits.gz
# 2026-07-26 05:15:04 INFO     Roman Entrance Pupil: Loaded OPD from /home/runner/data/stpsf-data/upscaled_HST_OPD.fits
# 2026-07-26 05:15:04 INFO     Added pupil plane: Roman Entrance Pupil
# 2026-07-26 05:15:04 INFO     Added coordinate inversion plane: OTE exit pupil
# 2026-07-26 05:15:04 INFO     Added pupil plane: Field Dependent Aberration (WFI01)
# 2026-07-26 05:15:04 INFO     Added detector with pixelscale=0.1078577405 and oversampling=4: WFI detector
# 2026-07-26 05:15:04 INFO     Calculating PSF with 10 wavelengths
# 2026-07-26 05:15:04 INFO      Propagating wavelength = 9.4555e-07 m
# 2026-07-26 05:15:04 INFO      Propagating wavelength = 9.7265e-07 m
# 2026-07-26 05:15:04 INFO      Propagating wavelength = 9.9975e-07 m
# 2026-07-26 05:15:05 INFO      Propagating wavelength = 1.02685e-06 m
# 2026-07-26 05:15:05 INFO      Propagating wavelength = 1.05395e-06 m
# 2026-07-26 05:15:05 INFO      Propagating wavelength = 1.08105e-06 m
# 2026-07-26 05:15:06 INFO      Propagating wavelength = 1.10815e-06 m
# 2026-07-26 05:15:06 INFO      Propagating wavelength = 1.13525e-06 m
# 2026-07-26 05:15:06 INFO      Propagating wavelength = 1.16235e-06 m
# 2026-07-26 05:15:07 INFO      Propagating wavelength = 1.18945e-06 m
# 2026-07-26 05:15:07 INFO       Calculation completed in 3.290 s
# 2026-07-26 05:15:07 INFO     PSF Calculation completed.
# 2026-07-26 05:15:07 INFO     Calculating jitter using gaussian
# 2026-07-26 05:15:07 INFO     Jitter: Convolving with Gaussian with sigma=0.012 arcsec
# 2026-07-26 05:15:07 INFO             resulting image peak drops to 0.946 of its previous value
# 2026-07-26 05:15:07 INFO     Detector charge diffusion not applied because charge_diffusion_sigma option is 0
# 2026-07-26 05:15:07 INFO      Adding extension with image downsampled to detector pixel scale.
# 2026-07-26 05:15:07 INFO      Downsampling to detector pixel scale, by 4
# 2026-07-26 05:15:07 INFO      Downsampling to detector pixel scale, by 4
# 2026-07-26 05:15:11 WARNING  max(qe) > 1.1; this seems weird?!
# 2026-07-26 05:15:11 WARNING  Found 8 pixels with implied qe > 2; clipping these to qe 2
# 2026-07-26 05:15:11 INFO     Adding 1745 sources to image...
# 2026-07-26 05:15:48 INFO     Rendered 1600 point sources in 0.118 seconds
# 2026-07-26 05:15:48 INFO     Rendered 1745 total sources in 30 seconds
# 2026-07-26 05:15:50 INFO     Apportioning electrons to resultants...
# /home/runner/micromamba/envs/ci-env/lib/python3.13/site-packages/romanisim/persistence.py:252: RuntimeWarning: invalid value encountered in power
#   * (x / x0)**alpha * (dt / 1000)**(-gamma))
# 2026-07-26 05:20:26 INFO     Adding IPC...
# 2026-07-26 05:20:45 INFO     Adding read noise...
# 2026-07-26 05:21:26 INFO     Fitting ramps.
# 2026-07-26 05:21:45 INFO     Simulation complete.

# %% [markdown]
# This generates an L2 (or L1) image that can be used for further steps, like the commented sample below.

# %%
## Sample normalization of the data
#norm = simple_norm(im.data, "asinh", percent=99.7)
#plt.imshow(im.data, norm=norm, cmap="afmhot", origin="lower")

# %% [markdown]
# If saving the file on disk, uncomment the command below.
#
# In here we first set the name with the parameters defined above and extension for the data calibration level selected.

# %%
## Only change the first part up to _WFI
## to change the rootname of the file.
#cal_level = "cal" if level == 2 else "uncal"
#filename = (
#    f"r0003201001001001004_0001_wfi{sca:02d}_{optical_element.lower()}_{cal_level}.asdf"
#)
#
#im.meta.filename = filename
#af = asdf.AsdfFile()
#af.tree = {'roman': im}
#af.write_to(filename)

# %% [markdown]
# If we want to simulate an L1 ramp cube, then we can change the level variable above to 1, which will also change the output file name to `*_uncal.asdf`. The rest of the information stays the same.
#
# Once we finish working with the simulated file, it is recommended to erase the image from memory. This will free resources to create more simulations.

# %%
# Clean up the memory
del im, extras

# %% [markdown]
# ## Advanced Use Cases
# ### Dithered Observations
# Dithering is the process of shifting the telescope position slightly such that astronomical sources fall on different pixel positions in consecutive observations. Dithers comes in two flavors:
# - Large dithers: Used to fill the gaps between detectors and to reject pixels affected by undesirable effects
# - Sub-pixel dithers: Used for sampling the point spread function (PSF)
#
# If we want to create a set of dithered observations, we need to determine the new pointing of the WFI. Here we introduce a Python class that can take an initial right ascension, declination, and position angle of the WFI and then apply offsets to update those parameters for a new pointing. First, let's import some new packages and modules that will help, specifically:
# - *pysiaf* for WFI coordinate transformations
# - *dataclasses* for simplifying the definition of a class
# - *typing* for type hinting of inputs and outputs
#
# In this section, we show you how to determine the pointing positions necessary for dithering with the Roman WFI. In the [Advanced Use Cases - Simulating Dithered Observations in Parallel](#Simulating-Dithered-Observations-in-Parallel) section, we combine the dithering information and parallelization with Dask to show how to put this information to use.

# %%
import pysiaf
from dataclasses import dataclass
from typing import Union

# %% [markdown]
# Next, we create a Python class called `PointWFI` that takes three inputs: ra, dec, and roll_angle. Defining a class may be a little complicated for those who are new to Python, so don't worry too much about the details for now. Just know that this class takes your input position, creates an attitude matrix for the spacecraft using PySIAF, applies the offsets, and updates the pointing information.

# %%
@dataclass(init=True, repr=True)
class PointWFI:
    """
    Inputs
    ------
    ra (float): Right ascension of the target placed at the geometric
                center of the Wide Field Instrument (WFI) focal plane
                array. This has units of degrees.
    dec (float): Declination of the target placed at the geometric
                 center of the WFI focal plane array. This has units
                 of degrees.
    position_angle (float): Position angle of the WFI relative to the V3 axis
                            measured from North to East. A value of 0.0 degrees
                            would place the WFI in the "smiley face" orientation
                            (U-shaped) on the celestial sphere. To place WFI
                            such that the position angle of the V3 axis is
                            zero degrees, use a WFI position angle of -60 degrees.

    Description
    -----------
    To use this class, insantiate it with your initial pointing like so:

        >>> point = PointWFI(ra=30, dec=-45, position_angle=10)

    and then dither using the dither method:

        >>> point.dither(x_offset=10, y_offset=140)

    This would shift the WFI 10 arcseconds along the X-axis of the WFI
    and 140 arcseconds along the Y-axis of the WFI. These axes are in the ideal
    coordinate system of the WFI, i.e, with the WFI oriented in a U-shape with
    +x to the right and +y up. You can pull the new pointing info out of the object
    either as attributes or by just printing the object:

        >>> print(point.ra, point.dec)
        >>> 29.95536280064078 -44.977122003232786

    or

        >>> point
        >>> PointWFI(ra=29.95536280064078, dec=-44.977122003232786, position_angle=10)
    """

    # Set default pointing parameters
    ra: float = 0.0
    dec: float = 0.0
    position_angle: float = -60.0

    # Post init method sets some other defaults and initializes
    # the attitude matrix using PySIAF.
    def __post_init__(self) -> None:
        self.siaf_aperture = pysiaf.Siaf('Roman')['WFI_CEN']
        self.v2_ref = self.siaf_aperture.V2Ref
        self.v3_ref = self.siaf_aperture.V3Ref
        self.attitude_matrix = pysiaf.utils.rotations.attitude(self.v2_ref, self.v3_ref, self.ra,
                                                               self.dec, self.position_angle)
        self.siaf_aperture.set_attitude_matrix(self.attitude_matrix)

        # Compute the V3 position angle
        self.tel_roll = pysiaf.utils.rotations.posangle(self.attitude_matrix, 0, 0)

        # Save initial pointing
        self.att0 = self.attitude_matrix.copy()

        # Save a copy of the input RA and Dec in case someone needs it
        self.ra0 = copy.copy(self.ra)
        self.dec0 = copy.copy(self.dec)

    def dither(self, x_offset: Union[int, float],
               y_offset: Union[int, float]) -> None:
        """
        Purpose
        -------
        Take in an ideal X and Y offset in arcseconds and shift the telescope
        pointing to that position.

        Inputs
        ------
        x_offset (float): The offset in arcseconds in the ideal X direction.

        y_offset (float): The offset in arcseconds in the ideal Y direction.
        """

        self.ra, self.dec = self.siaf_aperture.idl_to_sky(x_offset, y_offset)

# %% [markdown]
# Now let's dither the WFI. We will use the BOXGAP4 dither pattern for our example. See the RDox article on [WFI Dithering](https://roman-docs.stsci.edu/roman-instruments-home/wfi-imaging-mode-user-guide/observing-with-the-wfi-in-imaging-mode/wfi-dithering) for more information. Note that the dither offsets are represented in the ideal X and Y directions (this means that +X is to the right and +Y is up when the WFI is in the U-shaped orientation with WFI07 and WFI16 in the upper-right and upper-left corners, respectively). The offsets are in units of arcseconds, and each offset represents the offset from the initial starting position. Here is the pattern:
#
# | Dither Step | Offset X (arcsec) | Offset Y (arcsec) |
# | --- | --- | --- |
# | 0 | 0.00 | 0.00 |
# | 1 | -205.20 | 0.88 |
# | 2 | -204.32 | 206.08 |
# | 3 | 0.88 | 205.20 |
#
# Now let's instantiate the `PointWFI` object with our initial pointing and move to the first dither position:

# %%
pointing = PointWFI(ra=270.7, dec=-0.2, position_angle=0.0)
pointing.dither(x_offset=-205.20, y_offset=0.88)
print(pointing)
# Out:
# PointWFI(ra=np.float64(270.7282882327223), dec=np.float64(-0.15051433561208868), position_angle=0.0)

# %% [markdown]
# We can see that the WFI shifted slightly in both right ascension and declination, but not by -205.20 and +0.88 arcseconds. Remember that the WFI dither offsets are specified in a coordinate system local to the WFI, so the offsets on the sky will be different (hence the need for the class we created above). To make it easier to script our simulations, we can pull the variables out of the `pointing` object, such as below where we show how to retrieve the `.ra` attribute:

# %%
pointing.ra
# Out:
# np.float64(270.7282882327223)

# %% [markdown]
# ### Parallelized Simulations
# Often, we will want to run a simulation using multiple detectors rather than just one at a time. Looping over the above in a serial fashion can take quite a long time, so we want to parallelize the work. In the example below, we will show how to parallelize the procedure with `Dask`. These cells are commented out by default, so to run them you need to uncomment all of the lines. Comments in code cells are marked with two # symbols (e.g., `## Comment`), so be sure to remove only the leading single # symbol.

# %%
# %pip install dask[complete]
# Out:
# Requirement already satisfied: dask[complete] in /home/runner/micromamba/envs/ci-env/lib/python3.13/site-packages (2026.7.1)
# Requirement already satisfied: click>=8.1 in /home/runner/micromamba/envs/ci-env/lib/python3.13/site-packages (from dask[complete]) (8.4.2)
# Requirement already satisfied: cloudpickle>=3.0.0 in /home/runner/micromamba/envs/ci-env/lib/python3.13/site-packages (from dask[complete]) (3.1.2)
# Requirement already satisfied: fsspec>=2021.09.0 in /home/runner/micromamba/envs/ci-env/lib/python3.13/site-packages (from dask[complete]) (2026.6.0)
# Requirement already satisfied: packaging>=20.0 in /home/runner/micromamba/envs/ci-env/lib/python3.13/site-packages (from dask[complete]) (26.2)
# Requirement already satisfied: partd>=1.4.0 in /home/runner/micromamba/envs/ci-env/lib/python3.13/site-packages (from dask[complete]) (1.4.2)
# Requirement already satisfied: pyyaml>=5.4.1 in /home/runner/micromamba/envs/ci-env/lib/python3.13/site-packages (from dask[complete]) (6.0.3)
# Requirement already satisfied: toolz>=0.12.0 in /home/runner/micromamba/envs/ci-env/lib/python3.13/site-packages (from dask[complete]) (1.1.0)
# Requirement already satisfied: lz4>=4.3.2 in /home/runner/micromamba/envs/ci-env/lib/python3.13/site-packages (from dask[complete]) (4.4.5)
# Requirement already satisfied: locket in /home/runner/micromamba/envs/ci-env/lib/python3.13/site-packages (from partd>=1.4.0->dask[complete]) (1.0.0)
# Requirement already satisfied: numpy>=1.24 in /home/runner/micromamba/envs/ci-env/lib/python3.13/site-packages (from dask[complete]) (2.5.1)
# Requirement already satisfied: pandas>=2.0 in /home/runner/micromamba/envs/ci-env/lib/python3.13/site-packages (from dask[complete]) (3.0.5)
# Requirement already satisfied: pyarrow>=16.0 in /home/runner/micromamba/envs/ci-env/lib/python3.13/site-packages (from dask[complete]) (25.0.0)
# Requirement already satisfied: distributed<2026.7.2,>=2026.7.1 in /home/runner/micromamba/envs/ci-env/lib/python3.13/site-packages (from dask[complete]) (2026.7.1)
# Requirement already satisfied: bokeh>=3.1.0 in /home/runner/micromamba/envs/ci-env/lib/python3.13/site-packages (from dask[complete]) (3.9.2)
# Requirement already satisfied: jinja2>=2.10.3 in /home/runner/micromamba/envs/ci-env/lib/python3.13/site-packages (from dask[complete]) (3.1.6)
# Requirement already satisfied: msgpack>=1.0.2 in /home/runner/micromamba/envs/ci-env/lib/python3.13/site-packages (from distributed<2026.7.2,>=2026.7.1->dask[complete]) (1.2.1)
# Requirement already satisfied: psutil>=5.8.0 in /home/runner/micromamba/envs/ci-env/lib/python3.13/site-packages (from distributed<2026.7.2,>=2026.7.1->dask[complete]) (7.2.2)
# Requirement already satisfied: sortedcontainers>=2.0.5 in /home/runner/micromamba/envs/ci-env/lib/python3.13/site-packages (from distributed<2026.7.2,>=2026.7.1->dask[complete]) (2.4.0)
# Requirement already satisfied: tblib!=3.2.0,!=3.2.1,>=1.6.0 in /home/runner/micromamba/envs/ci-env/lib/python3.13/site-packages (from distributed<2026.7.2,>=2026.7.1->dask[complete]) (3.2.2)
# Requirement already satisfied: tornado>=6.2.0 in /home/runner/micromamba/envs/ci-env/lib/python3.13/site-packages (from distributed<2026.7.2,>=2026.7.1->dask[complete]) (6.5.7)
# Requirement already satisfied: zict>=3.0.0 in /home/runner/micromamba/envs/ci-env/lib/python3.13/site-packages (from distributed<2026.7.2,>=2026.7.1->dask[complete]) (3.0.0)
# Requirement already satisfied: contourpy>=1.2 in /home/runner/micromamba/envs/ci-env/lib/python3.13/site-packages (from bokeh>=3.1.0->dask[complete]) (1.3.3)
# Requirement already satisfied: narwhals>=1.13 in /home/runner/micromamba/envs/ci-env/lib/python3.13/site-packages (from bokeh>=3.1.0->dask[complete]) (2.24.0)
# Requirement already satisfied: pillow>=7.1.0 in /home/runner/micromamba/envs/ci-env/lib/python3.13/site-packages (from bokeh>=3.1.0->dask[complete]) (12.3.0)
# Requirement already satisfied: xyzservices>=2021.09.1 in /home/runner/micromamba/envs/ci-env/lib/python3.13/site-packages (from bokeh>=3.1.0->dask[complete]) (2026.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/runner/micromamba/envs/ci-env/lib/python3.13/site-packages (from jinja2>=2.10.3->dask[complete]) (3.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/runner/micromamba/envs/ci-env/lib/python3.13/site-packages (from pandas>=2.0->dask[complete]) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/runner/micromamba/envs/ci-env/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas>=2.0->dask[complete]) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from dask.distributed import Client

# %% [markdown]
# At this point, it's helpful to redefine our simulation call above as a single function:

# %%
def run_romanisim(catalog, ra=80.0, dec=30.0, obs_date='2026-10-31T00:00:00',
                  sca=1, expnum=1, optical_element='F106',
                  ma_table_number=3, level=2, filename='r0003201001001001004', seed=5346):

    cal_level = 'cal' if level == 2 else 'uncal'
    filename = f'{filename}_{expnum:04d}_wfi{sca:02d}_{optical_element.lower()}_{cal_level}.asdf'

    # Set reference files to None for CRDS
    for k in parameters.reference_data:
        parameters.reference_data[k] = None

    # Set Galsim RNG object
    rng = galsim.UniformDeviate(seed)

    # Set default persistance information
    persist = persistence.Persistence()

    # Set metadata
    metadata = ris.set_metadata(date=obs_date, bandpass=optical_element, sca=sca,
                                ma_table_number=ma_table_number, usecrds=True)

    # Update the WCS info
    wcs.fill_in_parameters(metadata, SkyCoord(ra, dec, unit='deg', frame='icrs'),
                           boresight=False, pa_aper=0.0)

    # Run the simulation using metadata value without saving any files
    im, extras = risim.simulate(metadata, full_catalog, usecrds=True,
                                psftype='stpsf', level=level,
                                persistence=persist, rng=rng
                                )

    # Since we are using this function to generate several files,
    # we will save the files to disk.
    im.meta.filename = filename
    af = asdf.AsdfFile()
    af.tree = {'roman': im}
    af.write_to(filename)

    # Clean up the memory
    del im, extras

# %% [markdown]
# Now we initialize the Dask `Client()` and pass our simulation jobs to it. Dask will take care of scheduling the jobs and allocating resources. That said, we do have to be careful to not overload the Client. Set the number of WFI detectors to be simulated in the for loop appropriately to `n_detectors = 3` for a large RRN server.
#
# The variable `offset` adds an offset to the numbering of the WFI detector names. If you want to simulate, e.g., detectors WFI01, WFI02, and WFI03, then set `n_detectors = 3` and `offset = 0`. If instead you want to simulate, e.g., detectors WFI04, WFI05, and WFI06, then set `n_detectors = 3` and `offset = 3`. The `expnum` variable lets you change the exposure number in the file name (this is useful if you are simulated a series of dithered observations).
#
# **WARNING:** Please be cautious when parallelizing tasks such as Roman I-Sim as it can easily consume all of your RRN resources if handled incorrectly!
#
# We have commented out the lines below. If you want to run the parallelized simulation, uncomment all of the lines in the following code cell.
#
# **Note:** This cell may take several minutes to run. In addition, logging messages from `romanisim` and its dependencies will appear cluttered as they are executing simultaneously.

# %%
# Number of detectors to simulate. Change offset to select
# higher detector IDs (e.g., n_detectors = 3 and offset = 3
# will simulate detectors WFI04, WFI05, and WFI06.
n_detectors = 3
offset = 0

# Change this to increment the exposure number in the simulation output filename
expnum = 1

# Set up Dask client
# Give each simulation call its own worker so that no one worker exceeds
# the allocated memory.
dask_client = Client(n_workers=n_detectors)

# Create simulation runs to send to the client
tasks = []
for i in range(n_detectors):

    # Create simulations with the full_catalog defined above and for 3
    # WFI detectors. Otherwise, use the default parameters.
    tasks.append(dask_client.submit(run_romanisim, full_catalog,
                                    **{'ra': pointing.ra, 'dec': pointing.dec, 'sca': (i + 1 + offset), 'expnum': expnum}))

# Wait for all tasks to complete
results = dask_client.gather(tasks)

# Don't forget to close the Dask client!
dask_client.close()
# Out:
# 2026-07-26 05:21:46 INFO     To route to workers diagnostics web server please install jupyter-server-proxy: python -m pip install jupyter-server-proxy
# 2026-07-26 05:21:47 INFO     State start
# 2026-07-26 05:21:47 INFO       Scheduler at:     tcp://127.0.0.1:40899
# 2026-07-26 05:21:47 INFO       dashboard at:  http://127.0.0.1:8787/status
# 2026-07-26 05:21:47 INFO     Registering Worker plugin shuffle
# 2026-07-26 05:21:47 INFO             Start Nanny at: 'tcp://127.0.0.1:40489'
# 2026-07-26 05:21:47 INFO             Start Nanny at: 'tcp://127.0.0.1:37229'
# 2026-07-26 05:21:47 INFO             Start Nanny at: 'tcp://127.0.0.1:39225'
# 2026-07-26 05:21:47 INFO     Register worker addr: tcp://127.0.0.1:44641 name: 1
# 2026-07-26 05:21:47 INFO     Starting worker compute stream, tcp://127.0.0.1:44641
# 2026-07-26 05:21:47 INFO     Starting established connection to tcp://127.0.0.1:58590
# 2026-07-26 05:21:47 INFO     Register worker addr: tcp://127.0.0.1:36823 name: 0
# 2026-07-26 05:21:47 INFO     Starting worker compute stream, tcp://127.0.0.1:36823
# 2026-07-26 05:21:47 INFO     Starting established connection to tcp://127.0.0.1:58574
# 2026-07-26 05:21:47 INFO     Register worker addr: tcp://127.0.0.1:41849 name: 2
# 2026-07-26 05:21:47 INFO     Starting worker compute stream, tcp://127.0.0.1:41849
# 2026-07-26 05:21:47 INFO     Starting established connection to tcp://127.0.0.1:58588
# 2026-07-26 05:21:47 INFO     Receive client connection: Client-e56f3fc2-88b1-11f1-8ddc-70a8a5430063
# 2026-07-26 05:21:47 INFO     Starting established connection to tcp://127.0.0.1:58606
# /home/runner/micromamba/envs/ci-env/lib/python3.13/site-packages/distributed/client.py:3429: UserWarning: Sending large graph of size 34.30 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# CRDS - INFO -  Fetching  /home/runner/crds_cache/references/roman/wfi/roman_wfi_dark_0496.asdf    5.7 K bytes  (1 / 8 files) (0 / 1.2 G bytes)
# CRDS - INFO -  Fetching  /home/runner/crds_cache/references/roman/wfi/roman_wfi_distortion_0006.asdf   11.3 K bytes  (2 / 8 files) (5.7 K / 1.2 G bytes)
# CRDS - INFO -  Fetching  /home/runner/crds_cache/references/roman/wfi/roman_wfi_gain_0021.asdf   67.1 M bytes  (3 / 8 files) (17.0 K / 1.2 G bytes)
# CRDS - INFO -  Fetching  /home/runner/crds_cache/references/roman/wfi/roman_wfi_dark_0301.asdf    5.7 K bytes  (1 / 8 files) (0 / 1.2 G bytes)
# CRDS - INFO -  Fetching  /home/runner/crds_cache/references/roman/wfi/roman_wfi_distortion_0004.asdf   11.3 K bytes  (2 / 8 files) (5.7 K / 1.2 G bytes)
# CRDS - INFO -  Fetching  /home/runner/crds_cache/references/roman/wfi/roman_wfi_gain_0023.asdf   67.1 M bytes  (3 / 8 files) (17.0 K / 1.2 G bytes)
# CRDS - INFO -  Fetching  /home/runner/crds_cache/references/roman/wfi/roman_wfi_inverselinearity_0053.asdf  469.8 M bytes  (4 / 8 files) (67.1 M / 1.2 G bytes)
# 2026-07-26 05:21:53 WARNING  7412 points with problematic saturation / inverse linearity values!
# 2026-07-26 05:21:53 INFO     Simulating filter F106...
# 2026-07-26 05:21:53 INFO     Creating PSF using stpsf
# 2026-07-26 05:21:55 INFO     Using pupil mask 'F062' and detector 'WFI01'.
# 2026-07-26 05:21:55 INFO     Using pupil mask 'F062' and detector 'WFI01'.
# 2026-07-26 05:21:55 INFO     Using pupil mask 'F106' and detector 'WFI01'.
# 2026-07-26 05:21:55 INFO     No source spectrum supplied, therefore defaulting to 5700 K blackbody
# 2026-07-26 05:21:55 INFO     Computing wavelength weights using synthetic photometry for F106...
# CRDS - INFO -  Fetching  /home/runner/crds_cache/references/roman/wfi/roman_wfi_linearity_0038.asdf  469.8 M bytes  (5 / 8 files) (536.9 M / 1.2 G bytes)
# 2026-07-26 05:21:55 INFO     Using pupil mask 'F106' and detector 'WFI01'.
# 2026-07-26 05:21:55 INFO     PSF calc using fov_arcsec = 5.000000, oversample = 4, number of wavelengths = 10
# 2026-07-26 05:21:55 INFO     Creating optical system model:
# 2026-07-26 05:21:55 INFO     Initialized OpticalSystem: Roman+WFI
# 2026-07-26 05:21:55 INFO     Roman Entrance Pupil: Loaded amplitude transmission from /home/runner/data/stpsf-data/WFI/pupils/RST_WIM_Filter_F106_WFI01.fits.gz
# 2026-07-26 05:21:55 INFO     Roman Entrance Pupil: Loaded OPD from /home/runner/data/stpsf-data/upscaled_HST_OPD.fits
# 2026-07-26 05:21:55 INFO     Added pupil plane: Roman Entrance Pupil
# 2026-07-26 05:21:55 INFO     Added coordinate inversion plane: OTE exit pupil
# 2026-07-26 05:21:55 INFO     Added pupil plane: Field Dependent Aberration (WFI01)
# 2026-07-26 05:21:55 INFO     Added detector with pixelscale=0.1078577405 and oversampling=4: WFI detector
# 2026-07-26 05:21:55 INFO     Calculating PSF with 10 wavelengths
# 2026-07-26 05:21:55 INFO      Propagating wavelength = 9.4555e-07 m
# CRDS - INFO -  Fetching  /home/runner/crds_cache/references/roman/wfi/roman_wfi_inverselinearity_0046.asdf  469.8 M bytes  (4 / 8 files) (67.1 M / 1.2 G bytes)
# CRDS - INFO -  Fetching  /home/runner/crds_cache/references/roman/wfi/roman_wfi_integralnonlinearity_0017.asdf   16.9 M bytes  (6 / 8 files) (1.0 G / 1.2 G bytes)
# CRDS - INFO -  Fetching  /home/runner/crds_cache/references/roman/wfi/roman_wfi_readnoise_0035.asdf   67.1 M bytes  (7 / 8 files) (1.0 G / 1.2 G bytes)
# CRDS - INFO -  Fetching  /home/runner/crds_cache/references/roman/wfi/roman_wfi_linearity_0042.asdf  469.8 M bytes  (5 / 8 files) (536.9 M / 1.2 G bytes)
# 2026-07-26 05:22:02 INFO      Propagating wavelength = 9.7265e-07 m
# 2026-07-26 05:22:03 INFO      Propagating wavelength = 9.9975e-07 m
# 2026-07-26 05:22:03 INFO      Propagating wavelength = 1.02685e-06 m
# CRDS - INFO -  Fetching  /home/runner/crds_cache/references/roman/wfi/roman_wfi_integralnonlinearity_0012.asdf   16.9 M bytes  (6 / 8 files) (1.0 G / 1.2 G bytes)
# CRDS - INFO -  Fetching  /home/runner/crds_cache/references/roman/wfi/roman_wfi_readnoise_0019.asdf   67.1 M bytes  (7 / 8 files) (1.0 G / 1.2 G bytes)
# CRDS - INFO -  Fetching  /home/runner/crds_cache/references/roman/wfi/roman_wfi_saturation_0032.asdf  134.2 M bytes  (8 / 8 files) (1.1 G / 1.2 G bytes)
# 2026-07-26 05:22:04 INFO      Propagating wavelength = 1.05395e-06 m
# CRDS - INFO -  Fetching  /home/runner/crds_cache/references/roman/wfi/roman_wfi_saturation_0022.asdf  134.2 M bytes  (8 / 8 files) (1.1 G / 1.2 G bytes)
# 2026-07-26 05:22:05 INFO      Propagating wavelength = 1.08105e-06 m
# CRDS - INFO -  Fetching  /home/runner/crds_cache/references/roman/wfi/roman_wfi_flat_0128.asdf  200.5 M bytes  (1 / 1 files) (0 / 200.5 M bytes)
# 2026-07-26 05:22:05 INFO      Propagating wavelength = 1.10815e-06 m
# 2026-07-26 05:22:06 INFO      Propagating wavelength = 1.13525e-06 m
# 2026-07-26 05:22:07 INFO      Propagating wavelength = 1.16235e-06 m
# 2026-07-26 05:22:07 INFO      Propagating wavelength = 1.18945e-06 m
# 2026-07-26 05:22:08 INFO       Calculation completed in 12.439 s
# 2026-07-26 05:22:08 INFO     PSF Calculation completed.
# 2026-07-26 05:22:08 INFO     Calculating jitter using gaussian
# 2026-07-26 05:22:08 INFO     Jitter: Convolving with Gaussian with sigma=0.012 arcsec
# 2026-07-26 05:22:08 INFO             resulting image peak drops to 0.946 of its previous value
# 2026-07-26 05:22:08 INFO     Detector charge diffusion not applied because charge_diffusion_sigma option is 0
# 2026-07-26 05:22:08 INFO      Adding extension with image downsampled to detector pixel scale.
# 2026-07-26 05:22:08 INFO      Downsampling to detector pixel scale, by 4
# 2026-07-26 05:22:08 INFO      Downsampling to detector pixel scale, by 4
# 2026-07-26 05:22:08 INFO     Creating PSF using stpsf
# 2026-07-26 05:22:08 INFO     Using pupil mask 'F062' and detector 'WFI01'.
# 2026-07-26 05:22:08 INFO     Using pupil mask 'F062' and detector 'WFI01'.
# 2026-07-26 05:22:08 INFO     Using pupil mask 'F106' and detector 'WFI01'.
# 2026-07-26 05:22:08 INFO     No source spectrum supplied, therefore defaulting to 5700 K blackbody
# 2026-07-26 05:22:08 INFO     Computing wavelength weights using synthetic photometry for F106...
# 2026-07-26 05:22:08 WARNING  318 points with problematic saturation / inverse linearity values!
# 2026-07-26 05:22:08 INFO     Using pupil mask 'F106' and detector 'WFI01'.
# 2026-07-26 05:22:08 INFO     PSF calc using fov_arcsec = 5.000000, oversample = 4, number of wavelengths = 10
# 2026-07-26 05:22:08 INFO     Creating optical system model:
# 2026-07-26 05:22:08 INFO     Initialized OpticalSystem: Roman+WFI
# 2026-07-26 05:22:09 INFO     Roman Entrance Pupil: Loaded amplitude transmission from /home/runner/data/stpsf-data/WFI/pupils/RST_WIM_Filter_F106_WFI01.fits.gz
# 2026-07-26 05:22:09 INFO     Roman Entrance Pupil: Loaded OPD from /home/runner/data/stpsf-data/upscaled_HST_OPD.fits
# 2026-07-26 05:22:09 INFO     Added pupil plane: Roman Entrance Pupil
# 2026-07-26 05:22:09 INFO     Added coordinate inversion plane: OTE exit pupil
# 2026-07-26 05:22:09 INFO     Added pupil plane: Field Dependent Aberration (WFI01)
# 2026-07-26 05:22:09 INFO     Added detector with pixelscale=0.1078577405 and oversampling=4: WFI detector
# 2026-07-26 05:22:09 INFO     Calculating PSF with 10 wavelengths
# 2026-07-26 05:22:09 INFO      Propagating wavelength = 9.4555e-07 m
# 2026-07-26 05:22:09 INFO     Simulating filter F106...
# 2026-07-26 05:22:09 INFO     Creating PSF using stpsf
# 2026-07-26 05:22:09 INFO      Propagating wavelength = 9.7265e-07 m
# 2026-07-26 05:22:10 INFO      Propagating wavelength = 9.9975e-07 m
# 2026-07-26 05:22:10 INFO     Using pupil mask 'F062' and detector 'WFI01'.
# 2026-07-26 05:22:10 INFO     Using pupil mask 'F062' and detector 'WFI03'.
# 2026-07-26 05:22:10 INFO     Using pupil mask 'F106' and detector 'WFI03'.
# 2026-07-26 05:22:10 INFO     No source spectrum supplied, therefore defaulting to 5700 K blackbody
# 2026-07-26 05:22:10 INFO     Computing wavelength weights using synthetic photometry for F106...
# 2026-07-26 05:22:11 INFO      Propagating wavelength = 1.02685e-06 m
# 2026-07-26 05:22:11 INFO     Using pupil mask 'F106' and detector 'WFI03'.
# 2026-07-26 05:22:11 INFO     PSF calc using fov_arcsec = 5.000000, oversample = 4, number of wavelengths = 10
# 2026-07-26 05:22:11 INFO     Creating optical system model:
# 2026-07-26 05:22:11 INFO     Initialized OpticalSystem: Roman+WFI
# 2026-07-26 05:22:11 INFO     Roman Entrance Pupil: Loaded amplitude transmission from /home/runner/data/stpsf-data/WFI/pupils/RST_WIM_Filter_F106_WFI03.fits.gz
# 2026-07-26 05:22:11 INFO     Roman Entrance Pupil: Loaded OPD from /home/runner/data/stpsf-data/upscaled_HST_OPD.fits
# 2026-07-26 05:22:11 INFO     Added pupil plane: Roman Entrance Pupil
# 2026-07-26 05:22:11 INFO     Added coordinate inversion plane: OTE exit pupil
# 2026-07-26 05:22:11 INFO     Added pupil plane: Field Dependent Aberration (WFI03)
# 2026-07-26 05:22:11 INFO     Added detector with pixelscale=0.1078577405 and oversampling=4: WFI detector
# 2026-07-26 05:22:11 INFO     Calculating PSF with 10 wavelengths
# 2026-07-26 05:22:11 INFO      Propagating wavelength = 9.4355e-07 m
# 2026-07-26 05:22:11 INFO      Propagating wavelength = 1.05395e-06 m
# 2026-07-26 05:22:12 INFO      Propagating wavelength = 1.08105e-06 m
# 2026-07-26 05:22:12 INFO      Propagating wavelength = 1.10815e-06 m
# 2026-07-26 05:22:13 INFO      Propagating wavelength = 1.13525e-06 m
# 2026-07-26 05:22:14 INFO      Propagating wavelength = 1.16235e-06 m
# 2026-07-26 05:22:14 INFO      Propagating wavelength = 1.18945e-06 m
# 2026-07-26 05:22:15 INFO       Calculation completed in 6.445 s
# 2026-07-26 05:22:15 INFO     PSF Calculation completed.
# 2026-07-26 05:22:15 INFO     Calculating jitter using gaussian
# 2026-07-26 05:22:15 INFO     Jitter: Convolving with Gaussian with sigma=0.012 arcsec
# 2026-07-26 05:22:15 INFO             resulting image peak drops to 0.946 of its previous value
# 2026-07-26 05:22:15 INFO     Detector charge diffusion not applied because charge_diffusion_sigma option is 0
# 2026-07-26 05:22:15 INFO      Adding extension with image downsampled to detector pixel scale.
# 2026-07-26 05:22:15 INFO      Downsampling to detector pixel scale, by 4
# 2026-07-26 05:22:15 INFO      Downsampling to detector pixel scale, by 4
# 2026-07-26 05:22:15 INFO     Creating PSF using stpsf
# 2026-07-26 05:22:15 INFO     Using pupil mask 'F062' and detector 'WFI01'.
# 2026-07-26 05:22:15 INFO     Using pupil mask 'F062' and detector 'WFI01'.
# 2026-07-26 05:22:15 INFO     Using pupil mask 'F106' and detector 'WFI01'.
# 2026-07-26 05:22:15 INFO     No source spectrum supplied, therefore defaulting to 5700 K blackbody
# 2026-07-26 05:22:15 INFO     Computing wavelength weights using synthetic photometry for F106...
# 2026-07-26 05:22:16 INFO     Using pupil mask 'F106' and detector 'WFI01'.
# 2026-07-26 05:22:16 INFO     PSF calc using fov_arcsec = 5.000000, oversample = 4, number of wavelengths = 10
# 2026-07-26 05:22:16 INFO     Creating optical system model:
# 2026-07-26 05:22:16 INFO     Initialized OpticalSystem: Roman+WFI
# CRDS - INFO -  Fetching  /home/runner/crds_cache/references/roman/wfi/roman_wfi_flat_0114.asdf  200.5 M bytes  (1 / 1 files) (0 / 200.5 M bytes)
# 2026-07-26 05:22:16 INFO     Roman Entrance Pupil: Loaded amplitude transmission from /home/runner/data/stpsf-data/WFI/pupils/RST_WIM_Filter_F106_WFI01.fits.gz
# 2026-07-26 05:22:16 INFO     Roman Entrance Pupil: Loaded OPD from /home/runner/data/stpsf-data/upscaled_HST_OPD.fits
# 2026-07-26 05:22:16 INFO     Added pupil plane: Roman Entrance Pupil
# 2026-07-26 05:22:16 INFO     Added coordinate inversion plane: OTE exit pupil
# 2026-07-26 05:22:16 INFO     Added pupil plane: Field Dependent Aberration (WFI01)
# 2026-07-26 05:22:16 INFO     Added detector with pixelscale=0.1078577405 and oversampling=4: WFI detector
# 2026-07-26 05:22:16 INFO     Calculating PSF with 10 wavelengths
# 2026-07-26 05:22:16 INFO      Propagating wavelength = 9.4555e-07 m
# 2026-07-26 05:22:17 INFO      Propagating wavelength = 9.7265e-07 m
# 2026-07-26 05:22:17 INFO      Propagating wavelength = 9.9975e-07 m
# 2026-07-26 05:22:18 INFO      Propagating wavelength = 9.7065e-07 m
# 2026-07-26 05:22:18 INFO      Propagating wavelength = 1.02685e-06 m
# 2026-07-26 05:22:18 INFO      Propagating wavelength = 9.9775e-07 m
# 2026-07-26 05:22:19 INFO      Propagating wavelength = 1.05395e-06 m
# 2026-07-26 05:22:19 WARNING  201 points with problematic saturation / inverse linearity values!
# 2026-07-26 05:22:19 INFO     Simulating filter F106...
# 2026-07-26 05:22:19 INFO      Propagating wavelength = 1.02485e-06 m
# 2026-07-26 05:22:19 INFO      Propagating wavelength = 1.08105e-06 m
# 2026-07-26 05:22:19 INFO     Creating PSF using stpsf
# 2026-07-26 05:22:20 INFO      Propagating wavelength = 1.05195e-06 m
# 2026-07-26 05:22:20 INFO      Propagating wavelength = 1.10815e-06 m
# 2026-07-26 05:22:20 INFO      Propagating wavelength = 1.07905e-06 m
# 2026-07-26 05:22:21 INFO      Propagating wavelength = 1.13525e-06 m
# 2026-07-26 05:22:21 INFO     Using pupil mask 'F062' and detector 'WFI01'.
# 2026-07-26 05:22:21 INFO     Using pupil mask 'F062' and detector 'WFI02'.
# 2026-07-26 05:22:21 INFO     Using pupil mask 'F106' and detector 'WFI02'.
# 2026-07-26 05:22:21 INFO     No source spectrum supplied, therefore defaulting to 5700 K blackbody
# 2026-07-26 05:22:21 INFO     Computing wavelength weights using synthetic photometry for F106...
# 2026-07-26 05:22:21 INFO      Propagating wavelength = 1.10615e-06 m
# 2026-07-26 05:22:21 INFO     Using pupil mask 'F106' and detector 'WFI02'.
# 2026-07-26 05:22:21 INFO     PSF calc using fov_arcsec = 5.000000, oversample = 4, number of wavelengths = 10
# 2026-07-26 05:22:21 INFO     Creating optical system model:
# 2026-07-26 05:22:21 INFO     Initialized OpticalSystem: Roman+WFI
# 2026-07-26 05:22:21 INFO     Roman Entrance Pupil: Loaded amplitude transmission from /home/runner/data/stpsf-data/WFI/pupils/RST_WIM_Filter_F106_WFI02.fits.gz
# 2026-07-26 05:22:21 INFO     Roman Entrance Pupil: Loaded OPD from /home/runner/data/stpsf-data/upscaled_HST_OPD.fits
# 2026-07-26 05:22:21 INFO     Added pupil plane: Roman Entrance Pupil
# 2026-07-26 05:22:21 INFO     Added coordinate inversion plane: OTE exit pupil
# 2026-07-26 05:22:21 INFO     Added pupil plane: Field Dependent Aberration (WFI02)
# 2026-07-26 05:22:21 INFO      Propagating wavelength = 1.16235e-06 m
# 2026-07-26 05:22:21 INFO     Added detector with pixelscale=0.1078577405 and oversampling=4: WFI detector
# 2026-07-26 05:22:21 INFO     Calculating PSF with 10 wavelengths
# 2026-07-26 05:22:21 INFO      Propagating wavelength = 9.4555e-07 m
# 2026-07-26 05:22:22 INFO      Propagating wavelength = 1.13325e-06 m
# 2026-07-26 05:22:22 INFO      Propagating wavelength = 1.18945e-06 m
# 2026-07-26 05:22:22 INFO      Propagating wavelength = 1.16035e-06 m
# 2026-07-26 05:22:23 INFO       Calculation completed in 6.695 s
# 2026-07-26 05:22:23 INFO     PSF Calculation completed.
# 2026-07-26 05:22:23 INFO     Calculating jitter using gaussian
# 2026-07-26 05:22:23 INFO     Jitter: Convolving with Gaussian with sigma=0.012 arcsec
# 2026-07-26 05:22:23 INFO             resulting image peak drops to 0.946 of its previous value
# 2026-07-26 05:22:23 INFO     Detector charge diffusion not applied because charge_diffusion_sigma option is 0
# 2026-07-26 05:22:23 INFO      Adding extension with image downsampled to detector pixel scale.
# 2026-07-26 05:22:23 INFO      Downsampling to detector pixel scale, by 4
# 2026-07-26 05:22:23 INFO      Downsampling to detector pixel scale, by 4
# 2026-07-26 05:22:23 INFO     Creating PSF using stpsf
# 2026-07-26 05:22:23 INFO     Using pupil mask 'F062' and detector 'WFI01'.
# 2026-07-26 05:22:23 INFO     Using pupil mask 'F062' and detector 'WFI01'.
# 2026-07-26 05:22:23 INFO     Using pupil mask 'F106' and detector 'WFI01'.
# 2026-07-26 05:22:23 INFO     No source spectrum supplied, therefore defaulting to 5700 K blackbody
# 2026-07-26 05:22:23 INFO     Computing wavelength weights using synthetic photometry for F106...
# 2026-07-26 05:22:23 INFO      Propagating wavelength = 1.18745e-06 m
# 2026-07-26 05:22:23 INFO     Using pupil mask 'F106' and detector 'WFI01'.
# 2026-07-26 05:22:23 INFO     PSF calc using fov_arcsec = 5.000000, oversample = 4, number of wavelengths = 10
# 2026-07-26 05:22:23 INFO     Creating optical system model:
# 2026-07-26 05:22:23 INFO     Initialized OpticalSystem: Roman+WFI
# 2026-07-26 05:22:24 INFO     Roman Entrance Pupil: Loaded amplitude transmission from /home/runner/data/stpsf-data/WFI/pupils/RST_WIM_Filter_F106_WFI01.fits.gz
# 2026-07-26 05:22:24 INFO     Roman Entrance Pupil: Loaded OPD from /home/runner/data/stpsf-data/upscaled_HST_OPD.fits
# 2026-07-26 05:22:24 INFO     Added pupil plane: Roman Entrance Pupil
# 2026-07-26 05:22:24 INFO     Added coordinate inversion plane: OTE exit pupil
# 2026-07-26 05:22:24 INFO     Added pupil plane: Field Dependent Aberration (WFI01)
# 2026-07-26 05:22:24 INFO     Added detector with pixelscale=0.1078577405 and oversampling=4: WFI detector
# 2026-07-26 05:22:24 INFO     Calculating PSF with 10 wavelengths
# 2026-07-26 05:22:24 INFO      Propagating wavelength = 9.4555e-07 m
# 2026-07-26 05:22:24 INFO       Calculation completed in 12.822 s
# 2026-07-26 05:22:24 INFO     PSF Calculation completed.
# 2026-07-26 05:22:24 INFO     Calculating jitter using gaussian
# 2026-07-26 05:22:24 INFO     Jitter: Convolving with Gaussian with sigma=0.012 arcsec
# 2026-07-26 05:22:24 INFO             resulting image peak drops to 0.947 of its previous value
# 2026-07-26 05:22:24 INFO     Detector charge diffusion not applied because charge_diffusion_sigma option is 0
# 2026-07-26 05:22:24 INFO      Adding extension with image downsampled to detector pixel scale.
# 2026-07-26 05:22:24 INFO      Downsampling to detector pixel scale, by 4
# 2026-07-26 05:22:24 INFO      Downsampling to detector pixel scale, by 4
# 2026-07-26 05:22:24 INFO     Creating PSF using stpsf
# 2026-07-26 05:22:24 INFO     Using pupil mask 'F062' and detector 'WFI01'.
# 2026-07-26 05:22:24 INFO     Using pupil mask 'F062' and detector 'WFI03'.
# 2026-07-26 05:22:24 INFO     Using pupil mask 'F106' and detector 'WFI03'.
# 2026-07-26 05:22:24 INFO     No source spectrum supplied, therefore defaulting to 5700 K blackbody
# 2026-07-26 05:22:24 INFO     Computing wavelength weights using synthetic photometry for F106...
# 2026-07-26 05:22:24 INFO      Propagating wavelength = 9.7265e-07 m
# 2026-07-26 05:22:24 INFO     Using pupil mask 'F106' and detector 'WFI03'.
# 2026-07-26 05:22:24 INFO     PSF calc using fov_arcsec = 5.000000, oversample = 4, number of wavelengths = 10
# 2026-07-26 05:22:24 INFO     Creating optical system model:
# 2026-07-26 05:22:24 INFO     Initialized OpticalSystem: Roman+WFI
# 2026-07-26 05:22:24 INFO     Roman Entrance Pupil: Loaded amplitude transmission from /home/runner/data/stpsf-data/WFI/pupils/RST_WIM_Filter_F106_WFI03.fits.gz
# 2026-07-26 05:22:24 INFO     Roman Entrance Pupil: Loaded OPD from /home/runner/data/stpsf-data/upscaled_HST_OPD.fits
# 2026-07-26 05:22:24 INFO     Added pupil plane: Roman Entrance Pupil
# 2026-07-26 05:22:24 INFO     Added coordinate inversion plane: OTE exit pupil
# 2026-07-26 05:22:24 INFO     Added pupil plane: Field Dependent Aberration (WFI03)
# 2026-07-26 05:22:25 INFO     Added detector with pixelscale=0.1078577405 and oversampling=4: WFI detector
# 2026-07-26 05:22:25 INFO     Calculating PSF with 10 wavelengths
# 2026-07-26 05:22:25 INFO      Propagating wavelength = 9.4355e-07 m
# 2026-07-26 05:22:25 INFO      Propagating wavelength = 9.9975e-07 m
# 2026-07-26 05:22:25 INFO      Propagating wavelength = 9.7065e-07 m
# 2026-07-26 05:22:26 INFO      Propagating wavelength = 1.02685e-06 m
# 2026-07-26 05:22:26 INFO      Propagating wavelength = 9.9775e-07 m
# 2026-07-26 05:22:26 INFO      Propagating wavelength = 1.05395e-06 m
# 2026-07-26 05:22:26 INFO      Propagating wavelength = 1.02485e-06 m
# 2026-07-26 05:22:27 INFO      Propagating wavelength = 1.08105e-06 m
# 2026-07-26 05:22:27 INFO      Propagating wavelength = 1.05195e-06 m
# 2026-07-26 05:22:28 INFO      Propagating wavelength = 1.10815e-06 m
# 2026-07-26 05:22:28 INFO      Propagating wavelength = 1.07905e-06 m
# 2026-07-26 05:22:28 INFO      Propagating wavelength = 1.13525e-06 m
# 2026-07-26 05:22:28 INFO      Propagating wavelength = 9.7265e-07 m
# 2026-07-26 05:22:29 INFO      Propagating wavelength = 1.10615e-06 m
# 2026-07-26 05:22:29 INFO      Propagating wavelength = 1.16235e-06 m
# 2026-07-26 05:22:29 INFO      Propagating wavelength = 9.9975e-07 m
# 2026-07-26 05:22:29 INFO      Propagating wavelength = 1.13325e-06 m
# 2026-07-26 05:22:30 INFO      Propagating wavelength = 1.18945e-06 m
# 2026-07-26 05:22:30 INFO      Propagating wavelength = 1.02685e-06 m
# 2026-07-26 05:22:30 INFO      Propagating wavelength = 1.16035e-06 m
# 2026-07-26 05:22:30 INFO       Calculation completed in 6.613 s
# 2026-07-26 05:22:30 INFO     PSF Calculation completed.
# 2026-07-26 05:22:30 INFO     Calculating jitter using gaussian
# 2026-07-26 05:22:30 INFO     Jitter: Convolving with Gaussian with sigma=0.012 arcsec
# 2026-07-26 05:22:30 INFO             resulting image peak drops to 0.946 of its previous value
# 2026-07-26 05:22:30 INFO     Detector charge diffusion not applied because charge_diffusion_sigma option is 0
# 2026-07-26 05:22:30 INFO      Adding extension with image downsampled to detector pixel scale.
# 2026-07-26 05:22:30 INFO      Downsampling to detector pixel scale, by 4
# 2026-07-26 05:22:30 INFO      Downsampling to detector pixel scale, by 4
# 2026-07-26 05:22:31 INFO      Propagating wavelength = 1.05395e-06 m
# 2026-07-26 05:22:31 INFO      Propagating wavelength = 1.18745e-06 m
# 2026-07-26 05:22:31 INFO      Propagating wavelength = 1.08105e-06 m
# 2026-07-26 05:22:31 INFO       Calculation completed in 6.875 s
# 2026-07-26 05:22:31 INFO     PSF Calculation completed.
# 2026-07-26 05:22:31 INFO     Calculating jitter using gaussian
# 2026-07-26 05:22:31 INFO     Jitter: Convolving with Gaussian with sigma=0.012 arcsec
# 2026-07-26 05:22:31 INFO             resulting image peak drops to 0.947 of its previous value
# 2026-07-26 05:22:31 INFO     Detector charge diffusion not applied because charge_diffusion_sigma option is 0
# 2026-07-26 05:22:31 INFO      Adding extension with image downsampled to detector pixel scale.
# 2026-07-26 05:22:31 INFO      Downsampling to detector pixel scale, by 4
# 2026-07-26 05:22:31 INFO      Downsampling to detector pixel scale, by 4
# 2026-07-26 05:22:31 INFO     Creating PSF using stpsf
# 2026-07-26 05:22:32 INFO     Using pupil mask 'F062' and detector 'WFI01'.
# 2026-07-26 05:22:32 INFO     Using pupil mask 'F062' and detector 'WFI03'.
# 2026-07-26 05:22:32 INFO     Using pupil mask 'F106' and detector 'WFI03'.
# 2026-07-26 05:22:32 INFO     No source spectrum supplied, therefore defaulting to 5700 K blackbody
# 2026-07-26 05:22:32 INFO     Computing wavelength weights using synthetic photometry for F106...
# 2026-07-26 05:22:32 INFO      Propagating wavelength = 1.10815e-06 m
# 2026-07-26 05:22:32 INFO     Using pupil mask 'F106' and detector 'WFI03'.
# 2026-07-26 05:22:32 INFO     PSF calc using fov_arcsec = 5.000000, oversample = 4, number of wavelengths = 10
# 2026-07-26 05:22:32 INFO     Creating optical system model:
# 2026-07-26 05:22:32 INFO     Initialized OpticalSystem: Roman+WFI
# 2026-07-26 05:22:32 INFO     Roman Entrance Pupil: Loaded amplitude transmission from /home/runner/data/stpsf-data/WFI/pupils/RST_WIM_Filter_F106_WFI03.fits.gz
# 2026-07-26 05:22:32 INFO     Roman Entrance Pupil: Loaded OPD from /home/runner/data/stpsf-data/upscaled_HST_OPD.fits
# 2026-07-26 05:22:32 INFO     Added pupil plane: Roman Entrance Pupil
# 2026-07-26 05:22:32 INFO     Added coordinate inversion plane: OTE exit pupil
# 2026-07-26 05:22:32 INFO     Added pupil plane: Field Dependent Aberration (WFI03)
# 2026-07-26 05:22:32 INFO     Added detector with pixelscale=0.1078577405 and oversampling=4: WFI detector
# 2026-07-26 05:22:32 INFO     Calculating PSF with 10 wavelengths
# 2026-07-26 05:22:32 INFO      Propagating wavelength = 9.4355e-07 m
# 2026-07-26 05:22:33 INFO      Propagating wavelength = 1.13525e-06 m
# 2026-07-26 05:22:33 INFO      Propagating wavelength = 9.7065e-07 m
# 2026-07-26 05:22:33 INFO      Propagating wavelength = 1.16235e-06 m
# 2026-07-26 05:22:34 INFO      Propagating wavelength = 9.9775e-07 m
# 2026-07-26 05:22:34 INFO      Propagating wavelength = 1.18945e-06 m
# 2026-07-26 05:22:34 INFO      Propagating wavelength = 1.02485e-06 m
# 2026-07-26 05:22:35 INFO       Calculation completed in 13.375 s
# 2026-07-26 05:22:35 INFO     PSF Calculation completed.
# 2026-07-26 05:22:35 INFO     Calculating jitter using gaussian
# 2026-07-26 05:22:35 INFO     Jitter: Convolving with Gaussian with sigma=0.012 arcsec
# 2026-07-26 05:22:35 INFO             resulting image peak drops to 0.946 of its previous value
# 2026-07-26 05:22:35 INFO     Detector charge diffusion not applied because charge_diffusion_sigma option is 0
# 2026-07-26 05:22:35 INFO      Adding extension with image downsampled to detector pixel scale.
# 2026-07-26 05:22:35 INFO      Downsampling to detector pixel scale, by 4
# 2026-07-26 05:22:35 INFO      Downsampling to detector pixel scale, by 4
# 2026-07-26 05:22:35 INFO     Creating PSF using stpsf
# 2026-07-26 05:22:35 WARNING  max(qe) > 1.1; this seems weird?!
# 2026-07-26 05:22:35 WARNING  Found 8 pixels with implied qe > 2; clipping these to qe 2
# 2026-07-26 05:22:35 INFO     Adding 1688 sources to image...
# 2026-07-26 05:22:35 INFO     Using pupil mask 'F062' and detector 'WFI01'.
# 2026-07-26 05:22:35 INFO     Using pupil mask 'F062' and detector 'WFI02'.
# 2026-07-26 05:22:35 INFO      Propagating wavelength = 1.05195e-06 m
# 2026-07-26 05:22:35 INFO     Using pupil mask 'F106' and detector 'WFI02'.
# 2026-07-26 05:22:35 INFO     No source spectrum supplied, therefore defaulting to 5700 K blackbody
# 2026-07-26 05:22:35 INFO     Computing wavelength weights using synthetic photometry for F106...
# 2026-07-26 05:22:35 INFO     Using pupil mask 'F106' and detector 'WFI02'.
# 2026-07-26 05:22:35 INFO     PSF calc using fov_arcsec = 5.000000, oversample = 4, number of wavelengths = 10
# 2026-07-26 05:22:35 INFO     Creating optical system model:
# 2026-07-26 05:22:35 INFO     Initialized OpticalSystem: Roman+WFI
# 2026-07-26 05:22:35 INFO     Roman Entrance Pupil: Loaded amplitude transmission from /home/runner/data/stpsf-data/WFI/pupils/RST_WIM_Filter_F106_WFI02.fits.gz
# 2026-07-26 05:22:35 INFO     Roman Entrance Pupil: Loaded OPD from /home/runner/data/stpsf-data/upscaled_HST_OPD.fits
# 2026-07-26 05:22:35 INFO     Added pupil plane: Roman Entrance Pupil
# 2026-07-26 05:22:35 INFO     Added coordinate inversion plane: OTE exit pupil
# 2026-07-26 05:22:35 INFO     Added pupil plane: Field Dependent Aberration (WFI02)
# 2026-07-26 05:22:35 INFO     Added detector with pixelscale=0.1078577405 and oversampling=4: WFI detector
# 2026-07-26 05:22:35 INFO     Calculating PSF with 10 wavelengths
# 2026-07-26 05:22:35 INFO      Propagating wavelength = 9.4555e-07 m
# 2026-07-26 05:22:35 INFO      Propagating wavelength = 1.07905e-06 m
# 2026-07-26 05:22:36 INFO      Propagating wavelength = 9.7265e-07 m
# 2026-07-26 05:22:36 INFO      Propagating wavelength = 1.10615e-06 m
# 2026-07-26 05:22:37 INFO      Propagating wavelength = 9.9975e-07 m
# 2026-07-26 05:22:37 INFO      Propagating wavelength = 1.13325e-06 m
# 2026-07-26 05:22:38 INFO      Propagating wavelength = 1.16035e-06 m
# 2026-07-26 05:22:38 INFO      Propagating wavelength = 1.02685e-06 m
# 2026-07-26 05:22:38 INFO      Propagating wavelength = 1.18745e-06 m
# 2026-07-26 05:22:38 INFO      Propagating wavelength = 1.05395e-06 m
# 2026-07-26 05:22:39 INFO       Calculation completed in 6.713 s
# 2026-07-26 05:22:39 INFO     PSF Calculation completed.
# 2026-07-26 05:22:39 INFO     Calculating jitter using gaussian
# 2026-07-26 05:22:39 INFO     Jitter: Convolving with Gaussian with sigma=0.012 arcsec
# 2026-07-26 05:22:39 INFO             resulting image peak drops to 0.946 of its previous value
# 2026-07-26 05:22:39 INFO     Detector charge diffusion not applied because charge_diffusion_sigma option is 0
# 2026-07-26 05:22:39 INFO      Adding extension with image downsampled to detector pixel scale.
# 2026-07-26 05:22:39 INFO      Downsampling to detector pixel scale, by 4
# 2026-07-26 05:22:39 INFO      Propagating wavelength = 1.08105e-06 m
# 2026-07-26 05:22:39 INFO      Downsampling to detector pixel scale, by 4
# 2026-07-26 05:22:39 INFO     Creating PSF using stpsf
# 2026-07-26 05:22:39 INFO     Using pupil mask 'F062' and detector 'WFI01'.
# 2026-07-26 05:22:39 INFO     Using pupil mask 'F062' and detector 'WFI03'.
# 2026-07-26 05:22:39 INFO     Using pupil mask 'F106' and detector 'WFI03'.
# 2026-07-26 05:22:39 INFO     No source spectrum supplied, therefore defaulting to 5700 K blackbody
# 2026-07-26 05:22:39 INFO     Computing wavelength weights using synthetic photometry for F106...
# 2026-07-26 05:22:40 INFO     Using pupil mask 'F106' and detector 'WFI03'.
# 2026-07-26 05:22:40 INFO     PSF calc using fov_arcsec = 5.000000, oversample = 4, number of wavelengths = 10
# 2026-07-26 05:22:40 INFO     Creating optical system model:
# 2026-07-26 05:22:40 INFO     Initialized OpticalSystem: Roman+WFI
# 2026-07-26 05:22:40 INFO      Propagating wavelength = 1.10815e-06 m
# 2026-07-26 05:22:40 INFO     Roman Entrance Pupil: Loaded amplitude transmission from /home/runner/data/stpsf-data/WFI/pupils/RST_WIM_Filter_F106_WFI03.fits.gz
# 2026-07-26 05:22:40 INFO     Roman Entrance Pupil: Loaded OPD from /home/runner/data/stpsf-data/upscaled_HST_OPD.fits
# 2026-07-26 05:22:40 INFO     Added pupil plane: Roman Entrance Pupil
# 2026-07-26 05:22:40 INFO     Added coordinate inversion plane: OTE exit pupil
# 2026-07-26 05:22:40 INFO     Added pupil plane: Field Dependent Aberration (WFI03)
# 2026-07-26 05:22:40 INFO     Added detector with pixelscale=0.1078577405 and oversampling=4: WFI detector
# 2026-07-26 05:22:40 INFO     Calculating PSF with 10 wavelengths
# 2026-07-26 05:22:40 INFO      Propagating wavelength = 9.4355e-07 m
# 2026-07-26 05:22:40 INFO      Propagating wavelength = 1.13525e-06 m
# 2026-07-26 05:22:40 INFO      Propagating wavelength = 9.7065e-07 m
# 2026-07-26 05:22:41 INFO      Propagating wavelength = 1.16235e-06 m
# 2026-07-26 05:22:41 INFO      Propagating wavelength = 9.9775e-07 m
# 2026-07-26 05:22:42 INFO      Propagating wavelength = 1.18945e-06 m
# 2026-07-26 05:22:42 INFO      Propagating wavelength = 1.02485e-06 m
# 2026-07-26 05:22:42 INFO       Calculation completed in 6.767 s
# 2026-07-26 05:22:42 INFO     PSF Calculation completed.
# 2026-07-26 05:22:42 INFO     Calculating jitter using gaussian
# 2026-07-26 05:22:42 INFO     Jitter: Convolving with Gaussian with sigma=0.012 arcsec
# 2026-07-26 05:22:42 INFO             resulting image peak drops to 0.946 of its previous value
# 2026-07-26 05:22:42 INFO     Detector charge diffusion not applied because charge_diffusion_sigma option is 0
# 2026-07-26 05:22:42 INFO      Adding extension with image downsampled to detector pixel scale.
# 2026-07-26 05:22:42 INFO      Downsampling to detector pixel scale, by 4
# 2026-07-26 05:22:42 INFO      Downsampling to detector pixel scale, by 4
# 2026-07-26 05:22:42 INFO     Creating PSF using stpsf
# 2026-07-26 05:22:42 INFO      Propagating wavelength = 1.05195e-06 m
# 2026-07-26 05:22:42 INFO     Using pupil mask 'F062' and detector 'WFI01'.
# 2026-07-26 05:22:42 INFO     Using pupil mask 'F062' and detector 'WFI02'.
# 2026-07-26 05:22:42 INFO     Using pupil mask 'F106' and detector 'WFI02'.
# 2026-07-26 05:22:42 INFO     No source spectrum supplied, therefore defaulting to 5700 K blackbody
# 2026-07-26 05:22:42 INFO     Computing wavelength weights using synthetic photometry for F106...
# 2026-07-26 05:22:43 INFO     Using pupil mask 'F106' and detector 'WFI02'.
# 2026-07-26 05:22:43 INFO     PSF calc using fov_arcsec = 5.000000, oversample = 4, number of wavelengths = 10
# 2026-07-26 05:22:43 INFO     Creating optical system model:
# 2026-07-26 05:22:43 INFO     Initialized OpticalSystem: Roman+WFI
# 2026-07-26 05:22:43 INFO     Roman Entrance Pupil: Loaded amplitude transmission from /home/runner/data/stpsf-data/WFI/pupils/RST_WIM_Filter_F106_WFI02.fits.gz
# 2026-07-26 05:22:43 INFO     Roman Entrance Pupil: Loaded OPD from /home/runner/data/stpsf-data/upscaled_HST_OPD.fits
# 2026-07-26 05:22:43 INFO     Added pupil plane: Roman Entrance Pupil
# 2026-07-26 05:22:43 INFO     Added coordinate inversion plane: OTE exit pupil
# 2026-07-26 05:22:43 INFO     Added pupil plane: Field Dependent Aberration (WFI02)
# 2026-07-26 05:22:43 INFO      Propagating wavelength = 1.07905e-06 m
# 2026-07-26 05:22:43 INFO     Added detector with pixelscale=0.1078577405 and oversampling=4: WFI detector
# 2026-07-26 05:22:43 INFO     Calculating PSF with 10 wavelengths
# 2026-07-26 05:22:43 INFO      Propagating wavelength = 9.4555e-07 m
# 2026-07-26 05:22:44 INFO      Propagating wavelength = 1.10615e-06 m
# 2026-07-26 05:22:44 INFO      Propagating wavelength = 9.7265e-07 m
# 2026-07-26 05:22:44 INFO      Propagating wavelength = 1.13325e-06 m
# 2026-07-26 05:22:44 INFO      Propagating wavelength = 9.9975e-07 m
# 2026-07-26 05:22:45 INFO      Propagating wavelength = 1.16035e-06 m
# 2026-07-26 05:22:45 INFO      Propagating wavelength = 1.02685e-06 m
# 2026-07-26 05:22:46 INFO      Propagating wavelength = 1.18745e-06 m
# 2026-07-26 05:22:46 INFO      Propagating wavelength = 1.05395e-06 m
# 2026-07-26 05:22:46 INFO       Calculation completed in 6.675 s
# 2026-07-26 05:22:46 INFO     PSF Calculation completed.
# 2026-07-26 05:22:46 INFO     Calculating jitter using gaussian
# 2026-07-26 05:22:46 INFO     Jitter: Convolving with Gaussian with sigma=0.012 arcsec
# 2026-07-26 05:22:46 INFO             resulting image peak drops to 0.946 of its previous value
# 2026-07-26 05:22:46 INFO     Detector charge diffusion not applied because charge_diffusion_sigma option is 0
# 2026-07-26 05:22:46 INFO      Adding extension with image downsampled to detector pixel scale.
# 2026-07-26 05:22:46 INFO      Downsampling to detector pixel scale, by 4
# 2026-07-26 05:22:46 INFO      Downsampling to detector pixel scale, by 4
# 2026-07-26 05:22:46 INFO      Propagating wavelength = 1.08105e-06 m
# 2026-07-26 05:22:47 INFO      Propagating wavelength = 1.10815e-06 m
# 2026-07-26 05:22:48 INFO      Propagating wavelength = 1.13525e-06 m
# 2026-07-26 05:22:49 INFO      Propagating wavelength = 1.16235e-06 m
# 2026-07-26 05:22:49 INFO      Propagating wavelength = 1.18945e-06 m
# 2026-07-26 05:22:50 INFO       Calculation completed in 6.830 s
# 2026-07-26 05:22:50 INFO     PSF Calculation completed.
# 2026-07-26 05:22:50 INFO     Calculating jitter using gaussian
# 2026-07-26 05:22:50 INFO     Jitter: Convolving with Gaussian with sigma=0.012 arcsec
# 2026-07-26 05:22:50 INFO             resulting image peak drops to 0.946 of its previous value
# 2026-07-26 05:22:50 INFO     Detector charge diffusion not applied because charge_diffusion_sigma option is 0
# 2026-07-26 05:22:50 INFO      Adding extension with image downsampled to detector pixel scale.
# 2026-07-26 05:22:50 INFO      Downsampling to detector pixel scale, by 4
# 2026-07-26 05:22:50 INFO      Downsampling to detector pixel scale, by 4
# 2026-07-26 05:22:50 INFO     Creating PSF using stpsf
# 2026-07-26 05:22:50 INFO     Using pupil mask 'F062' and detector 'WFI01'.
# 2026-07-26 05:22:50 INFO     Using pupil mask 'F062' and detector 'WFI02'.
# 2026-07-26 05:22:50 INFO     Using pupil mask 'F106' and detector 'WFI02'.
# 2026-07-26 05:22:50 INFO     No source spectrum supplied, therefore defaulting to 5700 K blackbody
# 2026-07-26 05:22:50 INFO     Computing wavelength weights using synthetic photometry for F106...
# 2026-07-26 05:22:51 INFO     Using pupil mask 'F106' and detector 'WFI02'.
# 2026-07-26 05:22:51 INFO     PSF calc using fov_arcsec = 5.000000, oversample = 4, number of wavelengths = 10
# 2026-07-26 05:22:51 INFO     Creating optical system model:
# 2026-07-26 05:22:51 INFO     Initialized OpticalSystem: Roman+WFI
# 2026-07-26 05:22:51 INFO     Roman Entrance Pupil: Loaded amplitude transmission from /home/runner/data/stpsf-data/WFI/pupils/RST_WIM_Filter_F106_WFI02.fits.gz
# 2026-07-26 05:22:51 INFO     Roman Entrance Pupil: Loaded OPD from /home/runner/data/stpsf-data/upscaled_HST_OPD.fits
# 2026-07-26 05:22:51 INFO     Added pupil plane: Roman Entrance Pupil
# 2026-07-26 05:22:51 INFO     Added coordinate inversion plane: OTE exit pupil
# 2026-07-26 05:22:51 INFO     Added pupil plane: Field Dependent Aberration (WFI02)
# 2026-07-26 05:22:51 INFO     Added detector with pixelscale=0.1078577405 and oversampling=4: WFI detector
# 2026-07-26 05:22:51 INFO     Calculating PSF with 10 wavelengths
# 2026-07-26 05:22:51 INFO      Propagating wavelength = 9.4555e-07 m
# 2026-07-26 05:22:51 WARNING  max(qe) > 1.1; this seems weird?!
# 2026-07-26 05:22:51 WARNING  Found 23 pixels with implied qe > 2; clipping these to qe 2
# 2026-07-26 05:22:51 INFO     Adding 1571 sources to image...
# 2026-07-26 05:22:51 INFO      Propagating wavelength = 9.7265e-07 m
# 2026-07-26 05:22:52 INFO      Propagating wavelength = 9.9975e-07 m
# 2026-07-26 05:22:53 INFO      Propagating wavelength = 1.02685e-06 m
# 2026-07-26 05:22:53 INFO      Propagating wavelength = 1.05395e-06 m
# 2026-07-26 05:22:54 INFO      Propagating wavelength = 1.08105e-06 m
# 2026-07-26 05:22:54 INFO      Propagating wavelength = 1.10815e-06 m
# 2026-07-26 05:22:55 INFO      Propagating wavelength = 1.13525e-06 m
# 2026-07-26 05:22:56 INFO      Propagating wavelength = 1.16235e-06 m
# 2026-07-26 05:22:56 INFO      Propagating wavelength = 1.18945e-06 m
# 2026-07-26 05:22:57 INFO       Calculation completed in 6.247 s
# 2026-07-26 05:22:57 INFO     PSF Calculation completed.
# 2026-07-26 05:22:57 INFO     Calculating jitter using gaussian
# 2026-07-26 05:22:57 INFO     Jitter: Convolving with Gaussian with sigma=0.012 arcsec
# 2026-07-26 05:22:57 INFO             resulting image peak drops to 0.946 of its previous value
# 2026-07-26 05:22:57 INFO     Detector charge diffusion not applied because charge_diffusion_sigma option is 0
# 2026-07-26 05:22:57 INFO      Adding extension with image downsampled to detector pixel scale.
# 2026-07-26 05:22:57 INFO      Downsampling to detector pixel scale, by 4
# 2026-07-26 05:22:57 INFO      Downsampling to detector pixel scale, by 4
# 2026-07-26 05:23:01 WARNING  max(qe) > 1.1; this seems weird?!
# 2026-07-26 05:23:01 WARNING  Found 3 pixels with implied qe > 2; clipping these to qe 2
# 2026-07-26 05:23:01 INFO     Adding 1597 sources to image...
# 2026-07-26 05:23:32 INFO     Rendered 1533 point sources in 0.125 seconds
# 2026-07-26 05:23:32 INFO     Rendered 1688 total sources in 41.8 seconds
# 2026-07-26 05:23:36 INFO     Apportioning electrons to resultants...
# 2026-07-26 05:23:42 INFO     Rendered 1426 point sources in 0.117 seconds
# 2026-07-26 05:23:42 INFO     Rendered 1571 total sources in 35 seconds
# 2026-07-26 05:23:45 INFO     Apportioning electrons to resultants...
# 2026-07-26 05:23:52 INFO     Rendered 1444 point sources in 0.121 seconds
# 2026-07-26 05:23:52 INFO     Rendered 1597 total sources in 34.8 seconds
# 2026-07-26 05:23:55 INFO     Apportioning electrons to resultants...
# /home/runner/micromamba/envs/ci-env/lib/python3.13/site-packages/romanisim/persistence.py:252: RuntimeWarning: invalid value encountered in power
#   * (x / x0)**alpha * (dt / 1000)**(-gamma))
# 2026-07-26 05:24:32 INFO     Adding IPC...
# 2026-07-26 05:24:36 INFO     Adding read noise...
# /home/runner/micromamba/envs/ci-env/lib/python3.13/site-packages/romanisim/persistence.py:252: RuntimeWarning: invalid value encountered in power
#   * (x / x0)**alpha * (dt / 1000)**(-gamma))
# 2026-07-26 05:24:42 INFO     Adding IPC...
# 2026-07-26 05:24:46 INFO     Adding read noise...
# 2026-07-26 05:24:49 INFO     Fitting ramps.
# /home/runner/micromamba/envs/ci-env/lib/python3.13/site-packages/romanisim/persistence.py:252: RuntimeWarning: invalid value encountered in power
#   * (x / x0)**alpha * (dt / 1000)**(-gamma))
# 2026-07-26 05:24:51 INFO     Adding IPC...
# /home/runner/micromamba/envs/ci-env/lib/python3.13/site-packages/romanisim/image.py:1133: RuntimeWarning: overflow encountered in cast
#   out[field] = fielddict[field].astype(dtype)
# 2026-07-26 05:24:54 INFO     Simulation complete.
# 2026-07-26 05:24:56 INFO     Adding read noise...
# 2026-07-26 05:25:00 INFO     Fitting ramps.
# 2026-07-26 05:25:05 INFO     Simulation complete.
# 2026-07-26 05:25:09 INFO     Fitting ramps.
# 2026-07-26 05:25:14 INFO     Simulation complete.
# 2026-07-26 05:25:14 INFO     Remove client Client-e56f3fc2-88b1-11f1-8ddc-70a8a5430063
# 2026-07-26 05:25:14 INFO     Received 'close-stream' from tcp://127.0.0.1:58606; closing.
# 2026-07-26 05:25:14 INFO     Remove client Client-e56f3fc2-88b1-11f1-8ddc-70a8a5430063
# 2026-07-26 05:25:14 INFO     Close client connection: Client-e56f3fc2-88b1-11f1-8ddc-70a8a5430063
# 2026-07-26 05:25:14 INFO     Retire worker addresses (stimulus_id='retire-workers-1785043514.7232606') (0, 1, 2)
# 2026-07-26 05:25:14 INFO     Closing Nanny at 'tcp://127.0.0.1:40489'. Reason: nanny-close
# 2026-07-26 05:25:14 INFO     Nanny asking worker to close. Reason: nanny-close
# 2026-07-26 05:25:14 INFO     Closing Nanny at 'tcp://127.0.0.1:37229'. Reason: nanny-close
# 2026-07-26 05:25:14 INFO     Nanny asking worker to close. Reason: nanny-close
# 2026-07-26 05:25:14 INFO     Closing Nanny at 'tcp://127.0.0.1:39225'. Reason: nanny-close
# 2026-07-26 05:25:14 INFO     Nanny asking worker to close. Reason: nanny-close
# 2026-07-26 05:25:14 INFO     Received 'close-stream' from tcp://127.0.0.1:58574; closing.
# 2026-07-26 05:25:14 INFO     Received 'close-stream' from tcp://127.0.0.1:58590; closing.
# 2026-07-26 05:25:14 INFO     Remove worker addr: tcp://127.0.0.1:36823 name: 0 (stimulus_id='handle-worker-cleanup-1785043514.7311175')
# 2026-07-26 05:25:14 INFO     Received 'close-stream' from tcp://127.0.0.1:58588; closing.
# 2026-07-26 05:25:14 INFO     Remove worker addr: tcp://127.0.0.1:44641 name: 1 (stimulus_id='handle-worker-cleanup-1785043514.7326827')
# 2026-07-26 05:25:14 INFO     Remove worker addr: tcp://127.0.0.1:41849 name: 2 (stimulus_id='handle-worker-cleanup-1785043514.7336876')
# 2026-07-26 05:25:14 INFO     Lost all workers
# 2026-07-26 05:25:14 INFO     Batched Comm Closed <TCP (closed) Scheduler connection to worker local=tcp://127.0.0.1:40899 remote=tcp://127.0.0.1:58588>
# Traceback (most recent call last):
#   File "/home/runner/micromamba/envs/ci-env/lib/python3.13/site-packages/distributed/batched.py", line 115, in _background_send
#     nbytes = yield coro
#              ^^^^^^^^^^
#   File "/home/runner/micromamba/envs/ci-env/lib/python3.13/site-packages/tornado/gen.py", line 783, in run
#     value = future.result()
#   File "/home/runner/micromamba/envs/ci-env/lib/python3.13/site-packages/distributed/comm/tcp.py", line 263, in write
#     raise CommClosedError()
# distributed.comm.core.CommClosedError
# 2026-07-26 05:25:15 INFO     Nanny at 'tcp://127.0.0.1:37229' closed.
# 2026-07-26 05:25:15 INFO     Nanny at 'tcp://127.0.0.1:40489' closed.
# 2026-07-26 05:25:15 INFO     Nanny at 'tcp://127.0.0.1:39225' closed.
# 2026-07-26 05:25:15 INFO     Closing scheduler. Reason: unknown
# 2026-07-26 05:25:15 INFO     Scheduler closing all comms

# %% [markdown]
# ### Simulating Dithered Observations in Parallel
# Now that we have demonstrated how to determine the WFI pointing positions necessary for any dither pattern, and how to parallelize Roman I-Sim simulations to simulate multiple detectors simultaneously, let's combine that information to simulate a series of dithered observations. As in the [Advanced Use Cases - Parallelized Simulations](#Parallelized-Simulations) section, we have commented out all of the code cells below.
#
# **Note:** If you have not reviewed the [Advanced Use Cases - Parallelized Simulations](#Parallelized-Simulations) section, please review the information in that part of the tutorial before proceeding. At a minimum, you will need to install Dask and define the Roman I-Sim wrapper function before running the cells below.
#
# We will use the four-point box gap-filling dither pattern described in [Advanced Use Cases - Dithered Observations](#Dithered-Observations). We will also re-use the Roman I-Sim wrapper function that we defined for Dask. As you can see in the cell below, we are simulating three WFI detectors at a time at each dither position before proceeding to the next dither position. At each dither position, we incrementally update the exposure number. The resulting file names are: `r0003201001001001004_XXXX_wfiNN_f106_uncal.asdf`, where XXXX is the zero-padded exposure number (e.g., 0001) and NN is the WFI detector ID (e.g., WFI01). Note that these are L1 files rather than the L2 file that was simulated previously.

# %%
## Initial pointing
#pointing = PointWFI(ra=270.94, dec=-0.2, position_angle=0.0)
#
## Number of detectors to simulate. Change offset to select
## higher detector IDs (e.g., n_detectors = 3 and offset = 3
## will simulate detectors WFI04, WFI05, and WFI06.
#n_detectors = 3
#offset = 0
#
## Change this to increment the exposure number
## in the simulation output filename
#expnum = 1
#
## Set up Dask client
## Give each simulation call its own worker so that no one worker
## exceeds the allocated memory.
#dask_client = Client(n_workers=n_detectors)
#
## Create simulation runs to send to the client
#tasks = []
#for i in range(n_detectors):
#
#    # Create simulations with the full_catalog defined above and for 3
#    # WFI detectors. Otherwise, use the default parameters.
#    tasks.append(dask_client.submit(run_romanisim, full_catalog,
#                                    **{'ra': pointing.ra, 'dec': pointing.dec, 'sca': i+1+offset, 'expnum': expnum, 'level': 1}))
#
## Wait for all tasks to complete
#results = dask_client.gather(tasks)
#
## Exposure 2
## Dither -205.20 +0.88
#pointing.dither(x_offset=-205.20, y_offset=0.88)
#expnum=2
#tasks = []
#for i in range(n_detectors):
#    tasks.append(dask_client.submit(run_romanisim, full_catalog,
#                                    **{'ra': pointing.ra, 'dec': pointing.dec, 'sca': i+1+offset, 'expnum': expnum, 'level': 1}))
#
## Wait for all tasks to complete
#results = dask_client.gather(tasks)
#
## Exposure 3
## Dither -204.32 +206.08
#pointing.dither(x_offset=-204.32, y_offset=206.08)
#expnum=3
#tasks = []
#for i in range(n_detectors):
#    tasks.append(dask_client.submit(run_romanisim, full_catalog,
#                                    **{'ra': pointing.ra, 'dec': pointing.dec, 'sca': i+1+offset, 'expnum': expnum, 'level': 1}))
#
## Wait for all tasks to complete
#results = dask_client.gather(tasks)
#
## Exposure 4
## Dither +0.88 +205.20
#pointing.dither(x_offset=0.88, y_offset=205.20)
#expnum=4
#tasks = []
#for i in range(n_detectors):
#    tasks.append(dask_client.submit(run_romanisim, full_catalog,
#                                    **{'ra': pointing.ra, 'dec': pointing.dec, 'sca': i+1+offset, 'expnum': expnum, 'level': 1}))
#
## Wait for all tasks to complete
#results = dask_client.gather(tasks)
#
## Don't forget to close the Dask client!
#dask_client.close()

# %% [markdown]
# ### Injecting Sources into L2 Images
# Another advanced use case is injecting sources into L2 images. This may be useful, for example, to assess completeness and to test systematics in our data (simulated or otherwise). We can also use this for creating time-variable sources in a series of simulations. Right now, Roman I-Sim only supports injection at L2, though work is underway to add this capability for L1 images in the future.
#
# To inject sources into a L2 image, we need to create a Roman I-Sim input catalog. However, the catalog will be a shortened version containing just the sources that we want to inject. Also recall that the catalog brightnesses are specified in units of maggies, which are defined such that one maggie is equal to the reference AB magnitude flux (3,631 Jy), i.e., maggies $\equiv 10^{-0.4m_{\mathrm{AB}}}$.
#
# First, let's read in a L2 file and display it. We will use one of the images we just simulated, but after it has been run through the Exposure Pipeline to generate the L2 file. You can either visit the [Exposure Pipeline](../exposure_pipeline/exposure_pipeline.ipynb) tutorial for more information to do this yourself, or use one of the files in the Nexus S3 bucket.

# %%
# Stream the files from the S3 bucket if they are not in local storage

if os.path.exists('r0003201001001001004_0001_wfi01_f106_cal.asdf'):
    dm = rdm.open('r0003201001001001004_0001_wfi01_f106_cal.asdf')
else:
    fs = s3fs.S3FileSystem(anon=True)
    asdf_dir_uri = "s3://stpubdata/roman/nexus/soc_simulations/tutorial_data/roman-2026.1/"
    asdf_file_uri = asdf_dir_uri + 'r0003201001001001004_0001_wfi01_f106_cal.asdf'
    with fs.open(asdf_file_uri, 'rb') as f:
        af = asdf.open(f)
        dm = rdm.open(af).copy()

# %% [markdown]
# Now let's take a look at our image around some area we would like to inject a new source. For this, let's choose pixel (X, Y) = (1000, 1000) to be the position of our new source, so we will display the area around that pixel. For more information on how to visualize your data, see the [Data Visualization](../data_visualization/data_visualization.ipynb) tutorial.

# %%
norm = simple_norm(dm.data, 'asinh', percent=99.7)
#plt.imshow(dm.data[900:1100, 900:1100], norm=norm, cmap='afmhot', origin='lower',
#           extent=[900, 1100, 900, 1100]);
plt.imshow(dm.data, norm=norm, cmap='afmhot', origin='lower')

# %%
zero_pix = dm.data[dm.data <= 0]
print(len(zero_pix))
# Out:
# 10943

# %% [markdown]
# Next, let's create our catalog. Let's choose a brightness of 2 x 10<sup>-8</sup> maggies (~19.25 AB magnitudes) for our source. Note that if you are injecting galaxies, then you will also need to supply the other parameters Roman I-Sim needs for galaxy sources (e.g., Sérsic index and half-light radius).
#
# In the next cell, we make a function for creating and saving our injection catalog:

# %%
# Define a function to create the catalog for sources
# that we want to inject into our L2 image.

def make_cat(ra, dec, fluxes, filename='injection_cat.ecsv'):

    filtlist = 'F062 F087 F106 F129 F146 F158 F184 F213'.split()
    tab = Table([ra, dec], names=('ra', 'dec'))
    src_types = np.array(['PSF' for i in ra])
    tab['type'] = src_types
    for k, v in fluxes.items():
        if k.upper() in filtlist:
            tab[k.upper()] = v
        else:
            raise ValueError(f'Incorrect filter name {k}!')

    tab.write(filename, overwrite=True)

# %% [markdown]
# And now run the function with our inputs:

# %%
# Get the RA and Dec from the WCS
ra, dec = dm.meta.wcs(1000, 1000)

# Make the injection catalog
make_cat([ra], [dec], {'F106': [2e-8]})

# %% [markdown]
# Let's take a look at the catalog we just created and make sure it looks correct:

# %%
tab = Table.read('injection_cat.ecsv')
tab
# Out:
# <Table length=1>
#         ra                 dec          type   F106
#      float64             float64        str3 float64
# ------------------ -------------------- ---- -------
# 270.69231500459955 -0.14630904322742877  PSF   2e-08

# %% [markdown]
# Previously in this tutorial, we wrote a function to run Roman I-Sim. In that function, we overrode all of the default parameters and set them to `None` to force Roman I-Sim to use calibration reference files from CRDS rather than the Roman I-Sim default scalar values. These default scalar values are intended to allow Roman I-Sim to in an offline mode when you may not have access to a CRDS cache or the CRDS server. However, the current version of the `inject_sources_into_l2()` function does not use CRDS reference files and must use the Roman I-Sim defaults. Because the injection needs the default parameter values, we need to restore them here. We accomplish that using Python's `importlib.reload()` function to reload the installed version of `romanisim.parameters` into memory:

# %%
importlib.reload(parameters)
# Out:
# <module 'romanisim.parameters' from '/home/runner/micromamba/envs/ci-env/lib/python3.13/site-packages/romanisim/parameters.py'>

# %% [markdown]
# Now we run the source injection function `inject_sources_into_l2()` with our image (datamodel), the injection catalog (the variable `tab`), and we set `stpsf=True` to use STPSF-generated point spread functions (PSFs) for the simulation. Notice that we make a copy of the image using the `.copy()` method so that we inject the source into a copy of the image rather than the original. This lets us compare the original and the updated version after we inject the source.
#
# As a reminder, this will use the default `Roman I-Sim` parameter values for the injected source; however, perhaps the most critical parameter (the gain) can be modified in the function call. The gain is important in the simulation as the WFI zeropoints in the L2 metadata are intended to transform from DN/s to MJy/sr, and therefore contain a factor of the gain. If needed, the gain value used in the zeropoint can be found in the photom reference file. In the cell below, we will set the gain to the default value (2 e<sup>–</sup>/DN).

# %%
result = inject_sources_into_l2(dm.copy(), tab, psftype="stpsf", gain=2)
# Out:
# 2026-07-26 05:25:18 INFO     Creating PSF using stpsf
# 2026-07-26 05:25:19 INFO     Using pupil mask 'F062' and detector 'WFI01'.
# 2026-07-26 05:25:19 INFO     Using pupil mask 'F062' and detector 'WFI01'.
# 2026-07-26 05:25:19 INFO     Using pupil mask 'F106' and detector 'WFI01'.
# 2026-07-26 05:25:19 INFO     No source spectrum supplied, therefore defaulting to 5700 K blackbody
# 2026-07-26 05:25:19 INFO     Computing wavelength weights using synthetic photometry for F106...
# 2026-07-26 05:25:19 INFO     Using pupil mask 'F106' and detector 'WFI01'.
# 2026-07-26 05:25:19 INFO     PSF calc using fov_arcsec = 5.000000, oversample = 4, number of wavelengths = 10
# 2026-07-26 05:25:19 INFO     Creating optical system model:
# 2026-07-26 05:25:19 INFO     Initialized OpticalSystem: Roman+WFI
# 2026-07-26 05:25:19 INFO     Roman Entrance Pupil: Loaded amplitude transmission from /home/runner/data/stpsf-data/WFI/pupils/RST_WIM_Filter_F106_WFI01.fits.gz
# 2026-07-26 05:25:19 INFO     Roman Entrance Pupil: Loaded OPD from /home/runner/data/stpsf-data/upscaled_HST_OPD.fits
# 2026-07-26 05:25:19 INFO     Added pupil plane: Roman Entrance Pupil
# 2026-07-26 05:25:19 INFO     Added coordinate inversion plane: OTE exit pupil
# 2026-07-26 05:25:19 INFO     Added pupil plane: Field Dependent Aberration (WFI01)
# 2026-07-26 05:25:19 INFO     Added detector with pixelscale=0.1078577405 and oversampling=4: WFI detector
# 2026-07-26 05:25:19 INFO     Calculating PSF with 10 wavelengths
# 2026-07-26 05:25:19 INFO      Propagating wavelength = 9.4555e-07 m
# 2026-07-26 05:25:19 INFO      Propagating wavelength = 9.7265e-07 m
# 2026-07-26 05:25:20 INFO      Propagating wavelength = 9.9975e-07 m
# 2026-07-26 05:25:20 INFO      Propagating wavelength = 1.02685e-06 m
# 2026-07-26 05:25:20 INFO      Propagating wavelength = 1.05395e-06 m
# 2026-07-26 05:25:21 INFO      Propagating wavelength = 1.08105e-06 m
# 2026-07-26 05:25:21 INFO      Propagating wavelength = 1.10815e-06 m
# 2026-07-26 05:25:21 INFO      Propagating wavelength = 1.13525e-06 m
# 2026-07-26 05:25:22 INFO      Propagating wavelength = 1.16235e-06 m
# 2026-07-26 05:25:22 INFO      Propagating wavelength = 1.18945e-06 m
# 2026-07-26 05:25:22 INFO       Calculation completed in 3.363 s
# 2026-07-26 05:25:22 INFO     PSF Calculation completed.
# 2026-07-26 05:25:22 INFO     Calculating jitter using gaussian
# 2026-07-26 05:25:22 INFO     Jitter: Convolving with Gaussian with sigma=0.012 arcsec
# 2026-07-26 05:25:22 INFO             resulting image peak drops to 0.946 of its previous value
# 2026-07-26 05:25:22 INFO     Detector charge diffusion not applied because charge_diffusion_sigma option is 0
# 2026-07-26 05:25:22 INFO      Adding extension with image downsampled to detector pixel scale.
# 2026-07-26 05:25:22 INFO      Downsampling to detector pixel scale, by 4
# 2026-07-26 05:25:22 INFO      Downsampling to detector pixel scale, by 4
# 2026-07-26 05:25:23 INFO     Adding 1 sources to image...
# 2026-07-26 05:25:23 WARNING  You requested fastpointsources, but the PSF and/or chromaticity are incompatible with this setting.  Disabling fastpointsources.
# 2026-07-26 05:25:23 INFO     Rendered 0 point sources in 0.00847 seconds
# 2026-07-26 05:25:23 INFO     Rendered 1 total sources in 0.033 seconds
# 2026-07-26 05:25:23 INFO     Fitting ramps.

# %% [markdown]
# Finally, let's re-plot the same region as before to show the injected source:

# %%
fig, axs = plt.subplots(nrows=1, ncols=2)

axs[0].imshow(dm.data[900:1100, 900:1100], norm=norm,
              cmap='afmhot', origin='lower',
              extent=[900, 1100, 900, 1100])

axs[0].set_title('Original')

axs[1].imshow(result.data[900:1100, 900:1100], norm=norm,
              cmap='afmhot', origin='lower',
              extent=[900, 1100, 900, 1100])

axs[1].set_title('Injected')

plt.tight_layout()

# %% [markdown]
# ## Additional Resources
# - [Roman I-Sim Documentation](https://romanisim.readthedocs.io/en/latest/index.html)
# - [RomanCal Documentation](https://roman-pipeline.readthedocs.io/en/latest/index.html)
# - [Roman Documentation System (RDox)](https://roman-docs.stsci.edu)

# %% [markdown]
# ***

# %% [markdown]
# ## What is next
# - Explore the Roman WFI data products with the [Working with ASDF](../working_with_asdf/working_with_asdf.ipynb) notebook.
# - Process Roman WFI raw (L1) data into exposure-level (L2) products using RomanCal with the [Exposure Pipeline](../exposure_pipeline/exposure_pipeline.ipynb) notebook.
# - Visualize Roman WFI exposure-level products using the [Data Visualization](../data_visualization/data_visualization.ipynb) notebook.
# - Combine multiple exposure-level (L2) products into mosaic-level (L3) images using the [Mosaic Pipeline](../mosaic_pipeline/mosaic_pipeline.ipynb)

# %% [markdown]
# ***

# %% [markdown]
# ## About this Notebook
# **Author:** Sanjib Sharma, Tyler Desjardins, Rosa Diaz<br>
# **Updated On:** 2026-04-28

# %% [markdown]
# <table width="100%" style="border:none; border-collapse:collapse;">
#
#
#   <tr style="border:none;">
#     <td style="border:none; width:180px; white-space:nowrap;">
#        <a href="#top" style="text-decoration:none; color:#0066cc;"> Top of page</a>
#     </td>
#     <td style="border:none; text-align:center;">
#         <img src="https://raw.githubusercontent.com/spacetelescope/roman_notebooks/refs/heads/main/roman_logo.png" alt="roman_logo" width="50px">
#     </td>
#     <td style="border:none; text-align:right;">
#        <img src="https://raw.githubusercontent.com/spacetelescope/roman_notebooks/refs/heads/main/stsci_logo2.png" width="90">
#     </td>
#   </tr>
# </table>
